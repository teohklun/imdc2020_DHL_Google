# %%
import import_ipynb
from Job import Job
from Vehicle import Vehicle
import importlib
import numpy as np
from typing import Dict, Tuple, Sequence, List, Any
import matplotlib.pyplot as plt
import folium
import pandas as pd 
import datetime

import json

import pprint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-6f5549638faa> in <module>
#       1 import import_ipynb
# ----> 2 from Job import Job
#       3 from Vehicle import Vehicle
#       4 import importlib
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'Job'

# %%
df = pd.read_csv("1.csv")
df
# Out:
#      PUD Svc Area PUD Fac PUD Rte PUD Cycle Courier id     Courier Type  \
# 0             KUL     EAC    ACA1         B   rafinord              NaN
# 1             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 2             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 3             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 4             KUL     EAC    ACA1         B   rafinord      DHL Courier
# ...           ...     ...     ...       ...        ...              ...
# 7603          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7604          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7605          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7606          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7607          KUL     EAC    ACQ2         B    ravenda  Service Partner
#
#                           Customer Name  \
# 0                                   NaN
# 1                 DHL EXPRESS M SDN BHD
# 2                        THIAM YEW CHUA
# 3                        FG FAMILY GOLD
# 4                             MANDY LEE
# ...                                 ...
# 7603  BAERLOCHER M TRADING AND SERVICES
# 7604                  EXIS TECH SDN BHD
# 7605                CPAK CERGAS SDN BHD
# 7606                 VS FAMILIA SDN BHD
# 7607                                NaN
#
#                                                  Street    zip      City  ...  \
# 0                                                   NaN    NaN       NaN  ...
# 1     LOT PT 13757,JALAN HARUAN 1\nOAKLAND INDUSTRIA...  70300  SEREMBAN  ...
# 2       249, JALAN 9, TAMAN BUKIT GALENA\nN/A\nSEREMBAN  70200  SEREMBAN  ...
# 3     NO.113, JLN KESUMA 4B / 1\nBDR TASIK KESUMA 40...  43700  BERANANG  ...
# 4     30 JALAN KESUMA 7/5\nBANDAR TASIK KESUMA SELAN...  43700  BERANANG  ...
# ...                                                 ...    ...       ...  ...
# 7603  SDN BHD. LOT 635 & 660 KAWASAN\nPERINDUSTRIAN ...  71450  SEREMBAN  ...
# 7604  LOT 26209, JALAN TJ 2/2\nTUANKU JAFFAR INDUSTR...  71450  SEREMBAN  ...
# 7605  LOT 22 JALAN BUNGA TANJUNG\nSENAWANG INDUSTRIA...  70400  SEREMBAN  ...
# 7606  LOT 71&72, JALAN PERNIAGAAN SENAWANG 1 TAMAN P...  70450  SEREMBAN  ...
# 7607                                                NaN    NaN       NaN  ...
#
#       Act Tm  Open Closed       lat        lgtd         awb_booking  \
# 0       9:20   NaN    NaN       NaN         NaN                 NaN
# 1       9:22   NaN  23:59       NaN         NaN          7511555413
# 2       9:39   NaN  23:59  2.729141  101.908920          8402377443
# 3      10:15  9:00  12:00  2.913812  101.872085          6224210694
# 4      10:20   NaN  23:59  2.898578  101.871412          4757007743
# ...      ...   ...    ...       ...         ...                 ...
# 7603   10:47   NaN    NaN  2.678117  102.004406          4106272435
# 7604   10:48   NaN  23:59  2.677906  102.004469          6791721963
# 7605   11:35  9:30  12:30  2.685681  101.987760          5521357940
# 7606   11:55  0:00  12:00  2.695789  101.967709  002918 - 550456849
# 7607   12:16   NaN  23:59  2.704715  101.916464                 NaN
#
#       Act Ckpt Code  PuD Type  Stop Code  MarkerColor
# 0             DEPAR       NaN        NaN          NaN
# 1                OK        DL        1.0          NaN
# 2                OK        DL        2.0          NaN
# 3                PU        PU        1.0          NaN
# 4                OK        DL        3.0          NaN
# ...             ...       ...        ...          ...
# 7603             PU        PU        3.0          NaN
# 7604             OK        DL        4.0          NaN
# 7605             PU        PU        4.0          NaN
# 7606             FP        FP        1.0          NaN
# 7607          ARRVD       NaN        NaN          NaN
#
# [7608 rows x 32 columns]

# %%
df.describe()
# Out:
#              Act Dt       ShpCnt  Pallets Pcs   Parcel Pcs    Total Pcs  \
# count  7.608000e+03  7492.000000  7492.000000  7492.000000  7011.000000
# mean   2.020022e+07     1.869995     0.111986     1.530833     2.839823
# std    8.056727e+00     3.236699     0.877723     8.108511     8.770209
# min    2.020020e+07     0.000000     0.000000     0.000000     0.000000
# 25%    2.020021e+07     1.000000     0.000000     0.000000     1.000000
# 50%    2.020022e+07     1.000000     0.000000     0.000000     1.000000
# 75%    2.020022e+07     2.000000     0.000000     1.000000     2.000000
# max    2.020023e+07    81.000000    34.000000   397.000000   397.000000
#
#             Weight          lat         lgtd    Stop Code  MarkerColor
# count  6808.000000  7368.000000  7368.000000  7008.000000          0.0
# mean     16.350611     2.767099   101.830914     8.759989          NaN
# std      90.419155     0.101424     0.124821     7.169603          NaN
# min       0.010000     2.418109   101.553258     1.000000          NaN
# 25%       0.180000     2.698712   101.718182     3.000000          NaN
# 50%       0.700000     2.732480   101.817228     7.000000          NaN
# 75%       4.382500     2.853820   101.923431    12.000000          NaN
# max    3021.000000     3.125483   102.096930    44.000000          NaN

# %%
df2 = df['Customer Name']

# %%
print(f"Duplicated rows: {df2.duplicated(keep=False)}")
# Out:
# Duplicated rows: 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 7603     True
# 7604     True
# 7605     True
# 7606     True
# 7607     True
# Name: Customer Name, Length: 7608, dtype: bool

# %%
morning_parcel = "2020/1/31 1:16" #yesterday afternoon onwards consider today morning
until_morning_parcel = "2020/2/1 09:15"

afternoon_parcel = "2020/2/1 09:16" #today until before go out consider today afternoon
until_afternoon_parcel = "2020/1/2 1:15"

subangLocation = [101.5531605, 3.0404532000000004]
firstFourHour = [0, 10800]
secondFourHour = [21600, 36000]

delivery = df.loc[df['Act Base'] == "D"]
pickup = df.loc[df['Act Base'] == "P"]

#no arrival time and delivery task can not be use
delivery = df.dropna(subset = ['AR dtm'])


delivery['AR dtm'] =  pd.to_datetime(delivery['AR dtm'], format='%d/%m/%Y %H:%M')

mask = (delivery['AR dtm'] >= morning_parcel) & (delivery['AR dtm'] <= until_morning_parcel)
dMorning = delivery.loc[mask]
dAfternoon = delivery.loc[~mask]

pickupDelivery = delivery.append(pickup, ignore_index=True)

pickupDeliveryMorning = dMorning.append(pickup, ignore_index=True)
pickupDeliveryAfternoon = dAfternoon.append(pickup, ignore_index=True)

# courierName = df["Courier id"].unique()
# zip = df["zip"].unique()
# vehiclesNumber = len(courierName)
# Out:
# C:\Users\lun\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pickupDeliveryAfternoon
single = pickupDeliveryMorning.loc[pickupDeliveryMorning['Courier id'] == "amohdol"]

single

vehiclesNumber = len(single)

# %%
vehicleList = []

for x in range(0, vehiclesNumber):
    vehicleList.append(Vehicle(x+1,subangLocation,[99999], zip , firstFourHour))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-63d302298dee> in <module>
#       2
#       3 for x in range(0, vehiclesNumber):
# ----> 4     vehicleList.append(Vehicle(x+1,subangLocation,[99999], zip , firstFourHour))
#
# NameError: name 'Vehicle' is not defined
