# %%
import import_ipynb

from Job import Job
from Vehicle import Vehicle

# %%
import importlib
import numpy as np
from typing import Dict, Tuple, Sequence, List, Any
import matplotlib.pyplot as plt
import folium
import pandas as pd 
import datetime
import types
import requests

from typing import Dict, Tuple, Sequence, List, Any
import polyline

import json

import pprint

 
import os
import pymysql
import pandas as pd

# %%
        from IPython.core.display import display, HTML
        display(HTML("""
        <style>
        #notebook-container {
            width: 100%
        }

        .code_cell {
           flex-direction: row !important;
        }

        .code_cell .input {
            width: 50%
        }

        .code_cell .output_wrapper {
            width: 50%
        }
        </style>
        """))
# Out:
# <style>
# #notebook-container {
#     width: 100%
# }
#
# .code_cell {
#    flex-direction: row !important;
# }
#
# .code_cell .input {
#     width: 50%
# }
#
# .code_cell .output_wrapper {
#     width: 50%
# }
# </style>

# %%
fullDataFrame = pd.read_csv("id3.csv")
date = "20200204"
# fullDataFrame = fullDataFrame.loc[(fullDataFrame['Courier Type'] != "NON_GCA5") ]

# # fullDataFrame = fullDataFrame.loc[(fullDataFrame["Courier Type"] == "NON_GCA5" )]
# fullDataFrame = fullDataFrame['awb_booking'].astype(str)
partialDataFrame = fullDataFrame.loc[fullDataFrame['Act Dt'] == int(date)]
partialDataFrame2 = fullDataFrame.loc[fullDataFrame['Act Dt'] == int(20200205)]

# # partialDataFrame

# fullDataFrame.rename( columns={'Unnamed: 0':'new column name'}, inplace=True )

# test = fullDataFrame.loc[fullDataFrame['new column name'] == 0]
# test
# # partialDataFrame.to_csv("partial.csv")
# # partialDataFrame.iloc[0]
# # fullDataFrame.iloc[0]

# row = test.iloc[0]
fullDataFrame = fullDataFrame.dropna(subset = ['lat', 'lgtd'])
geocode = []
# geocode[0] = fullDataFrame["lat"].to_list()
# geocode[1] = fullDataFrame["lgtd"].to_list()

for x in range(1000):
    geocode.append( str (fullDataFrame.iloc[x]["lgtd"] ) + "," + str(fullDataFrame.iloc[x]["lat"] ) )
    print(geocode[x] , end = ';')
# geocode
# Out:
# 101.9089202,2.7291413;101.8720849,2.9138122;101.8714116,2.8985776000000003;101.864946,2.8649815;101.9165453,2.7047678;101.9113186,2.7028412;101.7880696,2.7104468;101.7891044,2.7085251;101.7308882,2.7591918;101.7300218,2.7556603;101.7178744,2.7371452;101.7144491,2.7332567;101.7166783,2.727808;101.7172124,2.727366;101.7169605,2.7280959;101.7254744,2.7277763;101.7311247,2.7382047000000003;101.9166143,2.704694;101.9166143,2.704694;102.0055639,2.674632;101.916692,2.7048478;101.8062563,2.8255513;101.8176517,2.8286099;101.8232078,2.8396549;101.8219506,2.8397515;101.8156529,2.8658711;101.8086942,2.8669648;101.7995141,2.8595098;101.7786262,2.8249116;101.76098,2.8347447;101.7578797,2.8130394;101.7635632,2.8002267999999995;101.9014133,2.7257938;101.9165514,2.7048738;101.9165862,2.7048875;102.0153906,2.6743595;102.0075115,2.6743318;102.0061661,2.6742002;102.0051521,2.6746066;102.0079558,2.6740187;101.9768025,2.6891516;101.9166092,2.7047806;101.9168095,2.7046912999999995;101.9017394,2.7288386;101.8541654,2.9120303;101.8559516,2.9065425;101.8650443,2.9061238;101.8631
057737000000003;102.0738112,2.6057866;102.0738065,2.6057779;102.0741932,2.6058185000000003;102.0713361,2.6061996;101.9600837,2.7015373;101.9377683,2.7289348;101.9391753,2.7240464;101.9165844,2.7045494;101.9167616,2.7046183;101.923397,2.7024503;101.9208862,2.6995747000000003;101.9187714,2.6968734;101.9181425,2.6864598;101.9072051,2.6907491;101.9029322,2.6943228;101.9132589,2.6937234;101.912071,2.7015762000000003;101.9034964,2.7053752;101.9032526,2.6836142999999995;101.9007798,2.6782092;101.8980786,2.6775097000000003;101.9105973,2.6939857000000003;101.9233446,2.6902401;101.9263797,2.6870597000000003;101.9249233,2.6847295;101.9165088,2.7048194;101.7922938,2.5227154;101.7957005,2.5219517;101.7956737,2.5219692000000005;101.8101885,2.5283569;101.81019,2.5282972000000004;101.8128538,2.5291189;101.8217294,2.5288913;101.8316269,2.5174612;101.8527169,2.4777097;101.8070235,2.5409063;101.7969329,2.5384196;101.7969547,2.5385316;101.8103543,2.5597226;101.8184852,2.565769;101.8399043,2.6806706;101.8399706,2.6805424;101.8329007,2.6844727;101.8319758,2.6736865;101.8342183,2.6716248;101.8351822,2.6672467;101.8376098,2.6643133;101.8377559,2.6596594;101.8372862,2.6602016;101.834979,2.6637008;101.8350791,2.663733;101.8350402,2.6637201;101.8354265,2.6575297000000004;101.8334602,2.6817663;101.8605674,2.6763249;101.9106165,2.653365;101.9165339,2.7048877;102.005175,2.6744446;101.5658792,3.1249724;101.916762,2.7047502;101.6772775,2.7810484;101.70900290000002,2.7586828;101.7069228,2.7557611;101.7069274,2.7557987;101.7068458,2.7557414;101.6850706,2.7430092;101.68075,2.7427134;101.6807806,2.7426924;101.680316,2.8052748;101.6803876,2.8053766;101.68924859999998,2.8243852;101.7322582,2.8060597;101.73439559999998,2.8166303;101.7341806,2.8186284;101.7334483,2.8147491;101.7334483,2.8147491;101.7175854,2.794006;101.767672,2.7476532;101.7618562,2.7291592;101.7637658,2.7336791000000003;101.7671414,2.7310469;101.765313,2.7380575;101.9167102,2.7046313;101.9085206,2.6985642000000003;101.7230252,2.7189401;1 ...

# %%
test = fullDataFrame.loc[fullDataFrame['Courier id'] == "rafinord"] 
test2 = fullDataFrame.loc[fullDataFrame['Courier id'] == "ganejay"] 
print(test.empty)
# fullDataFrame.iloc[771]
# Out:
# False

# %%
test3.iloc[0]["Courier id"]
# Out:
# 'rafinord'

# %%
from google.cloud import storage
bucketName = "real-bucket-dhl"
pathForRead = 'gs://real-bucket-dhl/files/february/optimalRoutes.csv'
fileName = "files/february/optimalRoutes.csv"
# https://storage.cloud.google.com/real-bucket-dhl/files/february/optimalRoutes.csv
def checkGFileExists(fileName : str) -> bool:
    client = storage.Client()
    bucket = client.get_bucket(bucketName)
#     name = 'files/february/optimalRoutes.csv'
#     name = "files/february/response/20200204-a-447-response.json"
    return storage.Blob(bucket=bucket, name=fileName).exists(client)
print(not checkGFileExists(fileName))

if(not checkGFileExists(fileName)):
    print("here")
fullDataFrame = pd.read_csv(pathForRead)
print(fullDataFrame)
# Out:
# False
#    PUD Svc Area PUD Fac PUD Rte PUD Cycle Courier id     Courier Type  \
# 0           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 1           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 2           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 3           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 4           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 5           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 6           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 8           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 9           KUL     EAC    ACQ2         B    ravenda  Service Partner
# 10          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 11          KUL     EAC    ACQ2         B    ravenda  Service Partner
#
#                           Customer Name  \
# 0                                   NaN
# 1                      CIMB BANK BERHAD
# 2     AKASHI KIKAI INDUSTRY M SDN. BHD.
# 3   DAIHATSU PERODUA ENGINE MANUFACTURI
# 4      VIO STAR INTERNATIONAL M SDN BHD
# 5         PMP DRIVE SYSTEMS SEA SDN BHD
# 6                KOITO MALAYSIA SDN BHD
# 7   KAYAKU SAFETY SYSTEM MALAYSIA SDN B
# 8                  MEDIJOY INTERNATIONA
# 9         MEDIJOY INTERNATIONAL SDN BHD
# 10         DAIDONG ENGINEERING MALAYSIA
# 11                                  NaN
#
#                                                Street      zip      City  ...  \
# 0                                                 NaN      NaN       NaN  ...
# 1   TRADE SERVICES CENTRE\nNO 1A & 2BWISMA DPMNS 7...  70000.0  SEREMBAN  ...
# 2   PT. 11634, JALAN TECHVALLEY 3B/1,\nSENDAYAN TE...  71950.0  SEREMBAN  ...
# 3   PT 11690 JALAN TECHVALLEY 3/1\nSENDAYAN TECHVA...  71950.0  SEREMBAN  ...
# 4   LOT 46741, JLN TECHVALLEY 3/1,\nKWS PERINDUSTR...  71950.0  SEREMBAN  ...
# 5   LOT 12672, JALAN TECHVALLEY 2/1\nSENDAYAN TECH...  71950.0  SEREMBAN  ...
# 6   PT 12630, JLN TECHVALLEY 4/2\nKWSN PERIND SEND...  71950.0  SEREMBAN  ...
# 7   PT12627,PT12628&PT12629, JLN TECHVA\nSENDAYAN ...  71950.0  SEREMBAN  ...
# 8   PT12637,JALAN TECHVALLEY 3/2, SENDAYAN TECHVALLEY  71950.0  SEREMBAN  ...
# 9   PT12637,JALAN TECHVALLEY 3/2,\nSENDAYAN TECHVA...  71950.0  SEREMBAN  ...
# 10  LOT 11647 , JALAN TECHVALLEY 1/2\nSENDAYAN TEC...  71950.0  SEREMBAN  ...
# 11                                                NaN      NaN       NaN  ...
#
#     Closed       lat        lgtd         awb_booking Act Ckpt Code PuD Type  \
# 0    23:59  2.704840  101.916540                 NaN         DEPAR      NaN
# 1    17:00  2.727809  101.938337          4612256725            PU       PU
# 2    17:00  2.663629  101.834908          1613319680            PU       PU
# 3    23:59  2.659642  101.837782          9629692671            OK       DL
# 4    17:00  2.657187  101.835141          3464293361            PU       PU
# 5    17:00  2.667409  101.835091          2283329506            PU       PU
# 6    17:30  2.671066  101.834261          2412253616            PU       PU
# 7    17:00  2.673772  101.832205          6904540156            PU       PU
# 8    16:30  2.681693  101.833570  034802 - 550167321            FP       FP
# 9    16:30  2.681681  101.833595          2202062811            PU       PU
# 10   17:00  2.681217  101.839952          3260057452            PU       PU
# 11   23:59  2.704840  101.916540                 NaN         ARRVD      NaN
#
#     Stop Code  MarkerColor        id         batchID
# 0         NaN          NaN  697arrvd  20200204-a-697
# 1         5.0          NaN       571  20200204-a-697
# 2         8.0          NaN       610  20200204-a-697
# 3         5.0          NaN       609  20200204-a-697
# 4         7.0          NaN       608  20200204-a-697
# 5         9.0          NaN       611  20200204-a-697
# 6        10.0          NaN       612  20200204-a-697
# 7        11.0          NaN       613  20200204-a-697
# 8         2.0          NaN       615  20200204-a-697
# 9        12.0          NaN       614  20200204-a-697
# 10       13.0          NaN       616  20200204-a-697
# 11        NaN          NaN  697arrvd  20200204-a-697
#
# [12 rows x 34 columns]

# %%
test3
# Out:
#      PUD Svc Area PUD Fac PUD Rte PUD Cycle Courier id     Courier Type  \
# 0             KUL     EAC    ACA1         B   rafinord              NaN
# 1             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 2             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 3             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 4             KUL     EAC    ACA1         B   rafinord      DHL Courier
# ...           ...     ...     ...       ...        ...              ...
# 7513          KUL     EAC    ACY1         B    ganejay  Service Partner
# 7514          KUL     EAC    ACY1         B    ganejay  Service Partner
# 7515          KUL     EAC    ACY1         B    ganejay  Service Partner
# 7516          KUL     EAC    ACY1         B    ganejay  Service Partner
# 7517          KUL     EAC    ACY1         B    ganejay  Service Partner
#
#                     Customer Name  \
# 0                             NaN
# 1           DHL EXPRESS M SDN BHD
# 2                  THIAM YEW CHUA
# 3                  FG FAMILY GOLD
# 4                       MANDY LEE
# ...                           ...
# 7513                          NaN
# 7514            KJM ALUMINIUM CAN
# 7515  SEPANG AIRCRAFT ENGINEERING
# 7516     MR.MOHAMAD RASIDIN KASAN
# 7517                          NaN
#
#                                                  Street    zip       City  \
# 0                                                   NaN    NaN        NaN
# 1     LOT PT 13757,JALAN HARUAN 1\nOAKLAND INDUSTRIA...  70300   SEREMBAN
# 2       249, JALAN 9, TAMAN BUKIT GALENA\nN/A\nSEREMBAN  70200   SEREMBAN
# 3     NO.113, JLN KESUMA 4B / 1\nBDR TASIK KESUMA 40...  43700   BERANANG
# 4     30 JALAN KESUMA 7/5\nBANDAR TASIK KESUMA SELAN...  43700   BERANANG
# ...                                                 ...    ...        ...
# 7513                                                NaN    NaN        NaN
# 7514  NO. 106, JALAN PERMATA 1\nKAWASAN INDUSTRI ARA...  71800      NILAI
# 7515  LOT PT 16 JALAN KLIA\nSOUTHERN SUPPORT ZONE KL...  64000       KLIA
# 7516  38 MIRAGE BY THE LAKE\nJALAN SRI TASIK BARAT 1...  63000  CYBERJAYA
# 7517                                                NaN    NaN        NaN
#
#       ...  Open Closed       lat        lgtd awb_booking Act Ckpt Code  \
# 0     ...   NaN    NaN       NaN         NaN         NaN         DEPAR
# 1     ...   NaN  23:59       NaN         NaN  7511555413            OK
# 2     ...   NaN  23:59  2.729141  101.908920  8402377443            OK
# 3     ...  9:00  12:00  2.913812  101.872085  6224210694            PU
# 4     ...   NaN  23:59  2.898578  101.871412  4757007743            OK
# ...   ...   ...    ...       ...         ...         ...           ...
# 7513  ...   NaN  23:59  2.704705  101.917029         NaN         DEPAR
# 7514  ...   NaN  23:59  2.826847  101.808534  6410203166            HN
# 7515  ...   NaN  23:59  2.805450  101.725201  7036812031            HN
# 7516  ...   NaN  23:59  2.909826  101.655659  2665655705            HN
# 7517  ...   NaN  23:59  2.704551  101.916974         NaN         ARRVD
#
#       PuD Type  Stop Code  MarkerColor      id
# 0          NaN        NaN          NaN     1.0
# 1           DL        1.0          NaN     2.0
# 2           DL        2.0          NaN     3.0
# 3           PU        1.0          NaN     4.0
# 4           DL        3.0          NaN     5.0
# ...        ...        ...          ...     ...
# 7513       NaN        NaN          NaN  7531.0
# 7514        HN        1.0          NaN  7532.0
# 7515        HN        2.0          NaN  7533.0
# 7516        HN        3.0          NaN  7534.0
# 7517       NaN        NaN          NaN  7535.0
#
# [646 rows x 33 columns]

# %%
fullDataFrame.iloc[447]
# Out:
# PUD Svc Area                                                   KUL
# PUD Fac                                                        EAC
# PUD Rte                                                        NaN
# PUD Cycle                                                        B
# Courier id                                                rafinord
# Courier Type                                              NON_GCA5
# Customer Name                                                 name
# Street           Jalan Rumbia, Kampung Seberang Paya, 11900 Bay...
# zip                                                          11111
# City                                                           123
# Act Dt                                                    20200204
# Act Base                                                         P
# Delivery Type                                               NORMAL
# Pickup Type                                                REGULAR
# Prod Grp                                                     testG
# Prod Code                                                     test
# ShpCnt                                                           0
# Pallets Pcs                                                      0
# Parcel Pcs                                                       0
# Total Pcs                                                        0
# Weight                                                           0
# AR dtm                                                    20200204
# Act Tm                                                    09:01:00
# Open                                                      00:00:00
# Closed                                                    23:59:00
# lat                                                            NaN
# lgtd                                                           NaN
# awb_booking                                                 m_7589
# Act Ckpt Code                                                   OK
# PuD Type                                                   pudType
# Stop Code                                                      NaN
# MarkerColor                                                    NaN
# id                                                            7589
# Name: 447, dtype: object

# %%
dict_t = {"a" : {
    "b" : "c",
    "d" : "e"
                }
         }
test = {"a" : {
    "b" : "c",
                }
         }

dict_t ["a"] = test["a"]
del dict_t['a']

print(dict_t)
# for x in a["routes"]:
#     print(x)
# Out:
# {}

# %%
def getRouteIndexWithID(readed : dict, jobID :id)-> dict:
    for indexRoute, routes in enumerate( readed["routes"] , start = 0): 
        for indexStep, step in enumerate( routes["steps"], start = 1):
                if(step["type"] == "job"):
                    if(step["job"] == jobID):
                        return indexStep, indexRoute
    
    return [],[]
#     return 1,2,indexRoute

def getLocationsAscendingFromRoute(routes : dict, index :int):
    locations = []
    for step in routes["steps"]:
        locations.append(step["location"])
    return locations

def getRouteDetailWithID(ID):
    readed = getResponseFileAsDict()    
    indexStep, indexRoute = getRouteIndexWithID(readed, ID)
    if(indexStep == [] or indexRoute == []) :
        return [],[],[]
    else:
        locations = getLocationsAscendingFromRoute(readed["routes"][indexRoute], indexStep)
        idLocation = locations[indexStep]
        vehicleID = getRouteVehicleID(readed["routes"], indexRoute)

        return readed["routes"][indexRoute], indexStep, vehicleID

def getRouteVehicleID(routes, index):
    return routes[index]["vehicle"]
# Out:
# new column name           0
# PUD Svc Area            KUL
# PUD Fac                 EAC
# PUD Rte                ACA1
# PUD Cycle                 B
# Courier id         rafinord
# Courier Type            NaN
# Customer Name           NaN
# Street                  NaN
# zip                     NaN
# City                    NaN
# Act Dt             20200201
# Act Base                NaN
# Delivery Type           NaN
# Pickup Type             NaN
# Prod Grp                NaN
# Prod Code               NaN
# ShpCnt                  NaN
# Pallets Pcs             NaN
# Parcel Pcs              NaN
# Total Pcs               NaN
# Weight                  NaN
# AR dtm                  NaN
# Act Tm                 9:20
# Open                    NaN
# Closed                  NaN
# lat                     NaN
# lgtd                    NaN
# awb_booking             NaN
# Act Ckpt Code         DEPAR
# PuD Type                NaN
# Stop Code               NaN
# MarkerColor             NaN
# Name: 0, dtype: object

# %%
fullDataFrame
fullDataFrame = fullDataFrame[["Courier id", "zip"]]
fullDataFrame = fullDataFrame[fullDataFrame['zip'].notna()]


fullDataFrame = fullDataFrame[fullDataFrame["zip"].astype(str).str.isdigit()] 


test = fullDataFrame.groupby(["Courier id"])["zip"].aggregate(lambda x: set(map(int, x)))
test

print(test["amohdol"])
# Out:
# {71010, 63000, 71050, 42700, 71950, 70000, 43800, 70200, 71450, 70300}

# %%
fullDataFrame = pd.read_csv("1.csv")

fullDataFrame = fullDataFrame.loc[(fullDataFrame['Courier Type'] != "NON_GCA5") ]


fullDataFrame["id"] = fullDataFrame.index+1
fullDataFrame
# Out:
#      PUD Svc Area PUD Fac PUD Rte PUD Cycle Courier id     Courier Type  \
# 0             KUL     EAC    ACA1         B   rafinord              NaN
# 1             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 2             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 3             KUL     EAC    ACA1         B   rafinord      DHL Courier
# 4             KUL     EAC    ACA1         B   rafinord      DHL Courier
# ...           ...     ...     ...       ...        ...              ...
# 7603          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7604          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7605          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7606          KUL     EAC    ACQ2         B    ravenda  Service Partner
# 7607          KUL     EAC    ACQ2         B    ravenda  Service Partner
#
#                           Customer Name  \
# 0                                   NaN
# 1                 DHL EXPRESS M SDN BHD
# 2                        THIAM YEW CHUA
# 3                        FG FAMILY GOLD
# 4                             MANDY LEE
# ...                                 ...
# 7603  BAERLOCHER M TRADING AND SERVICES
# 7604                  EXIS TECH SDN BHD
# 7605                CPAK CERGAS SDN BHD
# 7606                 VS FAMILIA SDN BHD
# 7607                                NaN
#
#                                                  Street    zip      City  ...  \
# 0                                                   NaN    NaN       NaN  ...
# 1     LOT PT 13757,JALAN HARUAN 1\nOAKLAND INDUSTRIA...  70300  SEREMBAN  ...
# 2       249, JALAN 9, TAMAN BUKIT GALENA\nN/A\nSEREMBAN  70200  SEREMBAN  ...
# 3     NO.113, JLN KESUMA 4B / 1\nBDR TASIK KESUMA 40...  43700  BERANANG  ...
# 4     30 JALAN KESUMA 7/5\nBANDAR TASIK KESUMA SELAN...  43700  BERANANG  ...
# ...                                                 ...    ...       ...  ...
# 7603  SDN BHD. LOT 635 & 660 KAWASAN\nPERINDUSTRIAN ...  71450  SEREMBAN  ...
# 7604  LOT 26209, JALAN TJ 2/2\nTUANKU JAFFAR INDUSTR...  71450  SEREMBAN  ...
# 7605  LOT 22 JALAN BUNGA TANJUNG\nSENAWANG INDUSTRIA...  70400  SEREMBAN  ...
# 7606  LOT 71&72, JALAN PERNIAGAAN SENAWANG 1 TAMAN P...  70450  SEREMBAN  ...
# 7607                                                NaN    NaN       NaN  ...
#
#       Open Closed       lat        lgtd         awb_booking Act Ckpt Code  \
# 0      NaN    NaN       NaN         NaN                 NaN         DEPAR
# 1      NaN  23:59       NaN         NaN          7511555413            OK
# 2      NaN  23:59  2.729141  101.908920          8402377443            OK
# 3     9:00  12:00  2.913812  101.872085          6224210694            PU
# 4      NaN  23:59  2.898578  101.871412          4757007743            OK
# ...    ...    ...       ...         ...                 ...           ...
# 7603   NaN    NaN  2.678117  102.004406          4106272435            PU
# 7604   NaN  23:59  2.677906  102.004469          6791721963            OK
# 7605  9:30  12:30  2.685681  101.987760          5521357940            PU
# 7606  0:00  12:00  2.695789  101.967709  002918 - 550456849            FP
# 7607   NaN  23:59  2.704715  101.916464                 NaN         ARRVD
#
#       PuD Type  Stop Code  MarkerColor    id
# 0          NaN        NaN          NaN     1
# 1           DL        1.0          NaN     2
# 2           DL        2.0          NaN     3
# 3           PU        1.0          NaN     4
# 4           DL        3.0          NaN     5
# ...        ...        ...          ...   ...
# 7603        PU        3.0          NaN  7604
# 7604        DL        4.0          NaN  7605
# 7605        PU        4.0          NaN  7606
# 7606        FP        1.0          NaN  7607
# 7607       NaN        NaN          NaN  7608
#
# [7586 rows x 33 columns]

# %%
# Out:
# <class 'set'>
# {'71050', '70200', '70000', '42700', '71950', '70300', '71010', '63000', '43800', '71450'}
# ['71050', '70200', '70000', '42700', '71950', '70300', '71010', '63000', '43800', '71450']
# ['71050', '70200', '70000', '42700', '71950', '70300', '71010', '63000', '43800', '71450', 1]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-657b81824077> in <module>
# ----> 1 test2.index
#       2 a = set([])
#       3 dict_t = {}
#       4 for x in test2.index:
#       5     for y in x:
#
# NameError: name 'test2' is not defined

# %%
# Out:
#                        Act Dt  ShpCnt  Pallets Pcs  Parcel Pcs  Total Pcs  \
# Courier id zip
# amohdol    42700    505005287    45.0          1.0         6.0       48.0
#            43800     60600646    36.0          0.0         0.0       36.0
#            63000    383804332    32.0          0.0         1.0       32.0
#            70000     20200210     1.0          0.0         1.0        1.0
#            70200    929209870    77.0          2.0        39.0      104.0
# ...                       ...     ...          ...         ...        ...
# subrniam   71800  24018056452  2253.0        107.0      1176.0     2724.0
#            71807    585806252    67.0          7.0        54.0       89.0
#            71809    141401547    11.0          0.0        47.0       54.0
#            71900     40400428     2.0          0.0         1.0        2.0
#            9000      40400437     4.0          0.0         2.0        4.0
#
#                      Weight          lat           lgtd  Stop Code  \
# Courier id zip
# amohdol    42700    185.250    70.645254    2540.172673       93.0
#            43800     25.370     8.591013     304.916279        8.0
#            63000     20.110    55.576399    1931.524554      112.0
#            70000      4.450     2.672975     101.859613       23.0
#            70200    417.021   124.249203    4687.805327      327.0
# ...                     ...          ...            ...        ...
# subrniam   71800  10776.145  3353.527387  120340.551216    17961.0
#            71807    673.360    81.687714    2952.437666      378.0
#            71809    289.980    19.787120     712.731624       74.0
#            71900      3.620     5.444470     203.772146       34.0
#            9000       2.260     5.678688     203.651011        8.0
#
#                   MarkerColor
# Courier id zip
# amohdol    42700          0.0
#            43800          0.0
#            63000          0.0
#            70000          0.0
#            70200          0.0
# ...                       ...
# subrniam   71800          0.0
#            71807          0.0
#            71809          0.0
#            71900          0.0
#            9000           0.0
#
# [192 rows x 10 columns]
