# %%
import import_ipynb

# %%
        from IPython.core.display import display, HTML
        display(HTML("""
        <style>
        #notebook-container {
            width: 100%
        }

        .code_cell {
           flex-direction: row !important;
        }

        .code_cell .input {
            width: 50%
        }

        .code_cell .output_wrapper {
            width: 50%
        }
        </style>
        """))
# Out:
# <style>
# #notebook-container {
#     width: 100%
# }
#
# .code_cell {
#    flex-direction: row !important;
# }
#
# .code_cell .input {
#     width: 50%
# }
#
# .code_cell .output_wrapper {
#     width: 50%
# }
# </style>

# %%
#global param, config

bucketName = "real-bucket-dhl"
csvPath = "3.csv"
gStorage = 'gs://real-bucket-dhl/3.csv'

url = 'http://35.213.166.175:3000' #vroomRoute

date = "20200204"
session = "m"
street = "Jalan Rumbia, Kampung Seberang Paya, 11900 Bayan Lepas, Pulau Pinang"

defaultZip = 99
defaultCapacity = 99999

mode = "noCloud"
morningStart = "08:45:00"
morningEnd = "13:59:59"

afternoonStart = "14:00:00"
afternoonEnd = "20:00:00"

useZip = False
customCapacity = True

# %%
import re
# import import_ipynb
from job import Job
from vehicle import Vehicle
import importlib
import numpy as np
from typing import Dict, Tuple, Sequence, List, Any
import pandas as pd 
import datetime
import types
import requests

from typing import Dict, Tuple, Sequence, List, Any
# import polyline

import json

import pprint

 
import os
# import pymysql
import pandas as pd

import logging
import os
from google.cloud import storage

# when use flask open back
# from flask import Flask
from io import StringIO
# from flask import jsonifyaf


# datastore_client = datastore.Client()


# import google.cloud.storage as gcs
# import webapp2

# from google.appengine.api import app_identity
#[END imports]

#[START retries]
# my_default_retry_params = gcs.RetryParams(initial_delay=0.2,
#                                           max_delay=5.0,
#                                           backoff_factor=2,
#                                           max_retry_period=15)
# gcs.set_default_retry_params(my_default_retry_params)

# CLOUD_STORAGE_BUCKET = os.environ.get('CLOUD_STORAGE_BUCKET')
# # Create a Cloud Storage client.
# storage_client = gcs.Client()

# # Get the bucket that the file will be uploaded to.
# bucket = storage_client.get_bucket(CLOUD_STORAGE_BUCKET)

# def get(self):
#     # bucket_name = os.environ.get('BUCKET_NAME',
#     #                              app_identity.get_default_gcs_bucket_name())

#     # self.response.headers['Content-Type'] = 'text/plain'
#     # self.response.write('Demo GCS Application running from Version: '
#     #                     + os.environ['CURRENT_VERSION_ID'] + '\n')
#     # self.response.write('Using bucket name: ' + bucket_name + '\n\n')
# #[END get_default_bucket]

#     # bucket = '/' + bucket_name
#     filename = bucket + '/demo-testfile'
#     # self.tmp_filenames_to_clean_up = []

# def gcloudWriteFile(self, filename, content, optionWrite = "w"):
#     """Create a file.

#     The retry_params specified in the open call will override the default
#     retry params for this particular file handle.

#     Args:
#       filename: filename.
#     """
#     self.response.write('Creating file %s\n' % filename)

#     write_retry_params = gcs.RetryParams(backoff_factor=1.1)
#     gcs_file = gcs.open(filename,
#                         optionWrite,
#                         content_type='text/plain',
#                         options={'x-goog-meta-foo': 'foo',
#                                  'x-goog-meta-bar': 'bar'},
#                         retry_params=write_retry_params)
#     gcs_file.write(content)
#     gcs_file.close()
#     # self.tmp_filenames_to_clean_up.append(filename)

# def gcloudReadFile(self, filename):
#     self.response.write('Abbreviated file content (first line and last 1K):\n')

#     gcs_file = gcs.open(filename)
#     self.response.write(gcs_file.read())
#     contents = gcs_file.read()
#     gcs_file.close()

# def write_file(fileName : str, content : str):
#     text_file = open(fileName, "w")
#     n = text_file.write(content )
#     text_file.close()




def getResponseFileName(date : str, session : str )-> str:
#     from pathlib import Path

#     path = Path(__file__).parent / "../data/test.csv"
    return "files/february/response/" + str(date) + "-" + session + "-response.json"

def getInputeForResponseFileName(date: str, sesison: str) -> str:
    return "files/february/input/" + str(date) + "-" + session  + "-input.json"

# def saveRecordToDataBase(date : str, session : str) -> str: 
#     host = os.getenv('MYSQL_HOST')
#     port = os.getenv('MYSQL_PORT')
#     user = os.getenv('MYSQL_USER')
#     password = os.getenv('MYSQL_PASSWORD')
#     database = os.getenv('MYSQL_DATABASE')

#     json_file_name = getResponseFileName(date, session)
#     # json_file_name = "response.json"

#     conn = pymysql.connect(
#         host=host,
#         port=int(3306),
#         user="root",
#         passwd=password,
#         db="dhl-project",)
#     #     charset='utf8mb4')
#     try:
#         connObject = conn.cursor()
#         command = "INSERT INTO optimal_summary (date, session, response_name) VALUES (%s,%s,%s)"

#         connObject.execute(command, (date,session,json_file_name,))
#         # print(df)
#         conn.commit()

#     except Exception as e:
#         print("Exeception occured:{}".format(e))

#     finally:
#         conn.close()
#         return json_file_name
    
# def deleteRecordToDataBase(date : str, session : str): 
#     host = os.getenv('MYSQL_HOST')
#     port = os.getenv('MYSQL_PORT')
#     user = os.getenv('MYSQL_USER')
#     password = os.getenv('MYSQL_PASSWORD')
#     database = os.getenv('MYSQL_DATABASE')
#     # json_file_name = "response.json"

#     conn = pymysql.connect(
#         host=host,
#         port=int(3306),
#         user="root",
#         passwd=password,
#         db="dhl-project",)
#     #     charset='utf8mb4')
#     try:
#         connObject = conn.cursor()
#         command = "delete from optimal_summary where date = %s and session = %s"
#         connObject.execute(command, (date,session))
#         # print(df)
#         conn.commit()

#     except Exception as e:
#         print("Exeception occured:{}".format(e))

#     finally:
#         conn.close()

def write_file(fileName : str, content : str):

    text_file = open(fileName, "w")
    n = text_file.write(content )
    text_file.close()
    
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)
    
# def getTimeWindow(start, end):
    
def getMiliSec(time_str: float) -> int:
    """Get Seconds from time."""
#     if(type(time_str) == "float"):
#     if(type(time_str) is types.Float):
#             elif isinstance(obj, np.floating):

    time_str = str(time_str)
    if(len(time_str.split(':')) ==3  ):
        h, m,s = time_str.split(':')
    else:
        h, m = time_str.split(':')
        s= "00"
    
    return int(h) * 3600   + int(m) * 60 + int(s)

def getTimeWindow(start : float ,end : float) -> List:
    if(start != start ):
        start = "00:00:00"
#     if(end == "23:59"):
#         end = "20:00"
    if(end != end):
        end = "23:59:00"
    return [ getMiliSec(start), getMiliSec(end) ]

def getTime24hour(seconds : int):
    import datetime
    return str(datetime.timedelta(seconds=seconds))
    
def sendRequest(fileName : str):

    #payload = open("request.json")
    headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
    r = requests.post(url, data=open(fileName, 'rb'), headers=headers) 

#function declaration
def getActualQueryAdress(companyName: str, street : str)-> str:
    string = companyName + "+" + street
    return string

def parseStringToHtml(string :str) -> str:
    string  =string.replace(" ","+")
    return string

def getLocationWithStreetNameOrCustomerName(companyName: str, street : str) -> List:
    stringRquestStreet = getActualQueryAdress(parseStringToHtml(companyName), parseStringToHtml(street))
    api_key = "AIzaSyA2H1uflVbzM7wtGeMlbwpLKnMkFIJdWVc"
    url = 'https://maps.googleapis.com/maps/api/geocode/json?address=' + stringRquestStreet + ',+CA&key='+api_key+''
    # url = "https://maps.googleapis.com/maps/api/js?key="+api_key+"&libraries=places"
    # url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input="+stringRquestStreet+"&inputtype=textquery&fields=formatted_address,name,plus_code,geometry&key="+api_key+""
    # url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=BJ Court&inputtype=textquery&fields=formatted_address,name,plus_code,geometry&key="+api_key+""

    payload = {'key1': 'value1', 'key2': 'value2'}

    # POST with JSON 
    r = requests.post(url, data=json.dumps(payload))

    # Response, status etc
    r.text
    parsed = json.loads(r.text)

    return parsed["results"][0]["geometry"]["location"]

def getDeliveryRoute(partialDataFrame : List, fullDataFrame : List, session : str):
#     print("DASDASDDASDSDSDASDS")
    deliveryList = []
    deliveryListRoute=[]
    
    arraySearched = []
#     print(len(partialDataFrame))
#     for x in range(0, len(partialDataFrame)):
    for index, x in partialDataFrame.iterrows():
        valid = False
        if(x["Act Ckpt Code"] ==  "DEPAR" or x["Act Ckpt Code"]==  "ARRVD"):
#             valid = True
            
            if(x["Act Ckpt Code"] == "DEPAR"):
            
                subFrame = partialDataFrame.loc[partialDataFrame["Courier id"] == x["Courier id"]]
                subFrame.reset_index(inplace=True)
                arraySearched.append(x["Courier id"])

                countArraySearched = arraySearched.count(x["Courier id"])
                departTime = None
                arrivalTime = None
                counterLoop = 0
                indexFirst = subFrame.index[0]
                for index2, k in subFrame.iterrows():
                    if(counterLoop < countArraySearched):
                        if(k["Act Ckpt Code"] == "DEPAR"):
                            if(index2 != indexFirst):
                                if(subFrame.iloc[index2-1]["Act Ckpt Code"] != "ARRVD"):
                                    arrivalTime = None
                                    departTime = getMiliSec(k["Act Tm"])
                            else:
                                departTime = getMiliSec(k["Act Tm"])

                        if(k["Act Ckpt Code"] == "ARRVD"):
                            arrivalTime = getMiliSec(k["Act Tm"])
                            counterLoop+=1
                    else:
                        break

                if(session == "m"):
                    if(arrivalTime != None):
                        if( (departTime > getMiliSec(morningStart))  | ( arrivalTime > getMiliSec(morningEnd) ) ):
                            valid = True
                    elif((departTime > getMiliSec(morningStart)) & (departTime < getMiliSec(afternoonStart) ) ):
                            valid = True
                    else:
                        valid = False
                        print("unknow prepare sitaution 5")
                elif(session =="a"):
                    if(arrivalTime != None):
                        if( (departTime > getMiliSec(afternoonStart))  | ( arrivalTime < getMiliSec(afternoonEnd) )):
                            valid = True
                    elif(departTime > getMiliSec(afternoonStart) ):
                        valid = True
                    else:
                        valid = False
                        print("unknow prepare sitaution 6")
                else:
                    print("session error")
            
#             if(arrivalTime == arrivalTime):
#                 if( (session == "m") & (getMiliSec(departTime) > getMiliSec("08:45:00") ) & ( getMiliSec(arrivalTime) < getMiliSec("13:59:00") ) ):
#                     valid = True
#                 elif((session == "a")& (getMiliSec(departTime) > getMiliSec("14:00:00") ) & (getMiliSec(arrivalTime) < getMiliSec("23:59:00")  ) ):
#                     valid = True
#                 else:
#                     print("condition not meet")
#                     valid = False
#             elif( session == "m" & (getMilliSec(departTime) > getMiliSec("08:45:00") & getMilliSec(departTime) > getMiliSec("14:00:00") ):
#                  valid = True
#             elif( session == "a" & (getMilliSec(departTime) > getMiliSec("08:45:00") & getMilliSec(departTime) > getMiliSec("14:00:00") ) 
#                 valid = True
#             else:
#                 valid =False
#                  print("unknown situation 4")

                
            
#csv not two departure / arrival per session
#                             if( (session == "m") & 
#                                (getMiliSec(x["Act Tm"]) > getMiliSec("08:45") ) & 
#                                (getMiliSec(x["Act Tm"]) < getMiliSec("13:59") ) ):
#                     #                 print("here before")
#                                 valid = True
#                             elif( (session == "a") & 
#                                  (getMiliSec(x["Act Tm"]) > getMiliSec("14:00") )& 
#                                  (getMiliSec(x["Act Tm"]) < getMiliSec("23:59") ) ):
#                                 valid = True
#                             else:
#                     #                 print(x)
#                                 print("undefined session 222")
#                                 valid=False
            if(deliveryListRoute != []):
                deliveryList.append(deliveryListRoute)
                deliveryListRoute = []
            else:
                deliveryListRoute = []
        else:
#             if(valid):
            #logic for morning afternoon
            if( (session == "m") & (getMiliSec(x["Act Tm"]) > getMiliSec(morningStart) ) & (getMiliSec(x["Act Tm"]) < getMiliSec(morningEnd) ) ):
                valid = True
            elif( (session == "a") & (getMiliSec(x["Act Tm"]) > getMiliSec(afternoonStart) ) & (getMiliSec(x["Act Tm"]) < getMiliSec(afternoonEnd)  ) ) :
                valid = True
            else: #false for afternoon session first
                valid = False
            if(valid):
                if(x["lgtd"] != x["lgtd"] or x["lat"] != x["lat"]): # lat or long None
                    
                    if(mode == "noCloud"):
                        print("trigger no cloud geocode . . .")
                        lat = 2.7047421
                        lgtd = 101.9168708
                    else:
                        location = getLocationWithStreetNameOrCustomerName(x["Customer Name"], x["Street"])

                        lat = location["lat"]
                        lgtd = location["lng"]
        #                     print(lat)
                        #update the file
                        fullDataFrame.at[index, 'lat'] = lat
                        fullDataFrame.at[index, 'lgtd'] = lgtd
                    #update today
                    x["lat"] = lat
                    x["lgtd"] = lgtd
        if(valid):
            deliveryListRoute.append(x)
#     print(deliveryList[0])
    return deliveryList, fullDataFrame

def getTimeWindowWithSession(session : str) -> List:
    if(session == "m"):
#         timeWindow = getTimeWindow("09:00",  "18:45" )
#         timeWindow = getTimeWindow("09:00",  "13:45" )
        timeWindow = getTimeWindow(morningStart,  morningEnd )

    elif(session =="a"):
        timeWindow = getTimeWindow(afternoonStart,  afternoonEnd )
#         timeWindow = getTimeWindow("09:00",  "18:45" )

    else:
        print("undefined session")
        timeWindow = getTimeWindow("09:00:00",  "13:00:00" ) #default morning
        
    return timeWindow

def isNotNull(var):
    return var == var
def createJobsAndVehiclesList(deliveryList : List, timeWindow : List, zipSet :List):
    subangLocation = [101.9381 ,2.7297] #should be seremban
    jobList = []
    vehicleList = []
#     counter = 1
#     counter2 = 1
    deliveryOrPick = [1]
    duration = 300
#     print(deliveryList)
    for x in deliveryList:
        for y in x:
#             print(y["Act Ckpt Code"])
#             if(y["Act Ckpt Code"] == "ARRVD" or  y["Act Ckpt Code"] == "DEPAR"):
            if(y["Act Ckpt Code"]  == "DEPAR"): #just need to add one vehicle
                if(useZip):
                    vehicleList.append(Vehicle(y["id"],subangLocation, defaultCapacity, list(zipSet[y["Courier id"]]) + [defaultZip] , timeWindow, subangLocation, y["Courier id"]))
                else:
                    vehicleList.append(Vehicle(y["id"],subangLocation, defaultCapacity, [] , timeWindow, subangLocation, y["Courier id"]))

            #                 counter2+=1
            else:
                if(y["Act Ckpt Code"]  != "ARRVD"): 
    #                 print(y)
    #because the history actual time sometimes just does not fit in the range, so it will only be useful for new input
    # getTimeWindow(y["Open"], y["Closed"])
                    if(useZip):
                        jobList.append(Job(y["id"],deliveryOrPick,[y["lgtd"], y["lat"]] , [int(y["zip"])] if y["zip"] == y["zip"] else [defaultZip], [timeWindow], duration , y["Street"]  if y["Street"] == y["Street"] else "street is blank"        ))
                    else:
                        jobList.append(Job(y["id"],deliveryOrPick,[y["lgtd"], y["lat"]] , [], [timeWindow], duration , y["Street"]  if y["Street"] == y["Street"] else "street is blank"        ))
    #                 counter+=
    return jobList, vehicleList

def createDictionaryObjectJobsVehicles(jobsList : List,vehicleList : List) -> dict:
    dict_t = {}
    dict_t["jobs"] = []
    jobCounter = 0
    for x in jobsList:
        dict_t["jobs"].append(x.__dict__)
        jobCounter = jobCounter + 1

    dict_t["vehicles"] = []
    capacity = [  int (round(jobCounter/ len(vehicleList)) * 120 / 100 ) ]
    print("capacity : "  + str(capacity))
    for y in vehicleList:
        if(customCapacity):
#         y.capacity = [ round(jobCounter/ len(vehicleList)) + 1]
            y.capacity = capacity
#         y.capacity = [ round(jobCounter/ len(vehicleList))]

        #test.append(json.dumps(x.__dict__))
        dict_t["vehicles"].append(y.__dict__)
    return dict_t

# Function to insert row in the dataframe 
def addRowToDataFrame(row_number, df, row_value): 
    # Slice the upper half of the dataframe 
    df1 = df[0:row_number] 
   
    # Store the result of lower half of the dataframe 
    df2 = df[row_number:] 
   
    # Inser the row in the upper half dataframe 
    df1.loc[row_number]=row_value 
   
    # Concat the two dataframes 
    df_result = pd.concat([df1, df2]) 
   
    # Reassign the index labels 
    df_result.index = [*range(df_result.shape[0])] 
   
    # Return the updated dataframe 
    return df_result 

def addJob(dataFrame,date,session ,street, actBase = "P", openend = "00:00:00", closed = "23:59:00"):
    from numpy import nan as Nan

    actDt = int(date)
    street = street
    
#     if(openend == None):
#         openend = "00:00"
#     if(closed == None):
#         closed = "00:00"
        
    dateArrival = date
    pickUpType = "REGULAR"
    deliveryType = "NORMAL"
    
    name = "name"
    
    pudSvcArea = "KUL"
    pudType = "pudType"
    actCkpyCode = "OK"
    id = len(dataFrame) + 1
    awbBooking = session + "_" + str(id)
    closed = closed
    openend = openend
    
    
    if(session == "m"):
        actTm = "09:01:00"
    else:
        actTm = "15:00:00"
    
    dateArrival = dateArrival
    weight = 0
    tPcs = 0
    parcelPcs = 0
    shpCnt = 0
    palletPcs = 0
    parcelP = 0
    proCode = "test"
    prodGrp = "testG"
    pickUpType = pickUpType
    actBase = actBase
    city = "123"
    zip = "11111"
    street = street
    customerName = name
    if(dataFrame.all != dataFrame.all):
        print("dataFrame is blank array")
    courierID = dataFrame.iloc[0]["Courier id"]
    pudCycle = "B"
    pudEac = "EAC"
#     actDt = None

    new = pd.DataFrame({'PUD Svc Area': [pudSvcArea], 
                     'PUD Fac': [pudEac],
                     'PUD Cycle': [pudCycle],
                      'Courier id':courierID,
                      'Courier Type':  np.nan,
                      'Customer Name': [customerName],
                      'Street': [street],
                      'zip': [zip],
                      'City': [city],
                      'Act Dt': actDt,
                      'Act Base': [actBase],
                      'Delivery Type': [deliveryType],
                      'Pickup Type': [pickUpType],
                      'Prod Grp': [prodGrp],
                      'Prod Code': [proCode],
                      'ShpCnt': [shpCnt],
                      'Pallets Pcs': [palletPcs],
                      'Parcel Pcs': [parcelP],
                      'Total Pcs': [tPcs],
                      'Weight': [weight],
                      'AR dtm': [dateArrival],
                      'Act Tm': [actTm],
                      'Open': [openend],
                      'Closed': [closed],
                      'lat':  pd.Series([np.nan]),
                      'lgtd':  pd.Series([np.nan]),
                      'awb_booking': [awbBooking],
                      'Act Ckpt Code': [actCkpyCode],
                      'PuD Type': [pudType],
                      'Stop Code':  pd.Series([np.nan]),
                        'id' : [id],
                    'MarkerColor':  pd.Series([np.nan]), })
    
#     print(new.iloc[0]["Act Dt"])
    
    partialDataFrame = dataFrame.loc[(dataFrame['Courier id'] == courierID) & (dataFrame["Act Dt"] == int(date)) & (dataFrame["Act Ckpt Code"] == "DEPAR")]
    
#     print(partialDataFrame.index)
#     print(type(new.iloc[0]["Open"]))
    dataFrame = addRowToDataFrame(partialDataFrame.index[0] + 1, dataFrame, new.iloc[0])
#     dataFrame = dataFrame.append(new, ignore_index=True)
    
    return dataFrame,awbBooking

def gotUnssigned(dict_t : dict) -> str:
    if(dict_t != None and (dict_t["code"] != 0) ):
        return(dict_t["error"])
    else:
        return dict_t["unassigned"]

    
def routeWithDateAndSession(date : str,  session: str, street: None):

    # fullDataFrame = pd.read_csv("3.csv")
    fullDataFrame = pd.read_csv(csvPath)

    
    if(~(street != street)):
        fullDataFrame, newAwbBooking = addJob(fullDataFrame, date, session ,street)
    
    fullDataFrame = fullDataFrame.loc[(fullDataFrame['Courier Type'] != "NON_GCA5") ]
    partialDataFrame = fullDataFrame

    partialDataFrame = partialDataFrame.loc[partialDataFrame['Act Dt'] == int(date)]
#     partialDataFrame = partialDataFrame.sort_values('Courier id')
    #     fullDataFrame
    deliveryListRoute, fullDataFrame = getDeliveryRoute(partialDataFrame, fullDataFrame)
#     print(deliveryListRoute)
    jobsList, vehicleList = createJobsAndVehiclesList(deliveryListRoute, getTimeWindowWithSession(session))
    dict_t = createDictionaryObjectJobsVehicles(jobsList,vehicleList )

#     pprint.pprint(dict_t)
    content = json.dumps(dict_t, cls=NpEncoder) 
#     write_file("content.json", content)

    headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
    r = requests.post(url, data=open("content.json", 'rb'), headers=headers)    
    
    #record the response to file
    # json_file_name = saveRecordToDataBase(date, session)
    # deleteRecordToDataBase(date, session)
#     write_file(json_file_name, r.content)


    text_file = open(json_file_name, "wb")
    n = text_file.write(r.content )
    text_file.close()
    
#     #update the added job to csv
    fullDataFrame.to_csv(csvPath, index=False)
    
#     print(len(fullDataFrame))
#     print(partialDataFrame)
    return r

# r =routeWithDateAndSession(date, session, "Jalan Rumbia, Kampung Seberang Paya, 11900 Bayan Lepas, Pulau Pinang")

def getRouteIndexWithID(readed : dict, jobID :id)-> dict:
    for indexRoute, routes in enumerate( readed["routes"] , start = 0): 
        for indexStep, step in enumerate( routes["steps"], start = 1):
                if(step["type"] == "job"):
                    if(step["job"] == jobID):
                        return indexStep, indexRoute
    
    return [],[]
#     return 1,2,indexRoute

def getLocationsAscendingFromRoute(routes : dict, index :int):
    locations = []
    for step in routes["steps"]:
        locations.append(step["location"])
    return locations

def getRouteDetailWithID(ID):
    readed = getResponseFileAsDict()    
    indexStep, indexRoute = getRouteIndexWithID(readed, ID)
    if(indexStep == [] or indexRoute == []) :
        return [],[],[]
    else:
        locations = getLocationsAscendingFromRoute(readed["routes"][indexRoute], indexStep)
        idLocation = locations[indexStep]
        vehicleID = getRouteVehicleID(readed["routes"], indexRoute)

        return readed["routes"][indexRoute], indexStep, vehicleID

def getRouteVehicleID(routes, index):
    return routes[index]["vehicle"]

def tryGotUnassignedInResponse(date : str,  session: str, street: None, unassignedJob =None ):

    fullDataFrame = pd.read_csv(csvPath)
    if(~(street != street)):
        fullDataFrame, newAwbBooking = addJob(fullDataFrame, date, session, street)
    
    fullDataFrame = fullDataFrame.loc[(fullDataFrame['Courier Type'] != "NON_GCA5") ]
    partialDataFrame = fullDataFrame
    partialDataFrame = partialDataFrame.loc[partialDataFrame['Act Dt'] == int(date)]

    deliveryListRoute, fullDataFrame = getDeliveryRoute(partialDataFrame, fullDataFrame, session)
    jobsList, vehicleList = createJobsAndVehiclesList(deliveryListRoute, getTimeWindowWithSession(session))
    
    dict_t = createDictionaryObjectJobsVehicles(jobsList,vehicleList )
    print(len(deliveryListRoute))
    content = json.dumps(dict_t, cls=NpEncoder) 
    # write_file("tmp/content.json", content)

    gcloudWriteFile("content.json", content, "w")

    data = gcloudReadFile(filename)

    headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
    # r = requests.post(url, data=open("tmp/content.json", 'rb'), headers=headers)    
    r = requests.post(url, data=open(data, 'rb'), headers=headers)    
    
    # text_file = open(getResponseFileName(date, session), "wb")
    # n = text_file.write(r.content )
    # text_file.close()
    gcloudWriteFile(getResponseFileName(date, session), r.content, "wb")

def getResponseFileAsDict():
    import ndjson
    client = storage.Client()
    bucket = client.get_bucket(bucketName)
    blob = bucket.get_blob(getResponseFileName(date,session))
    json_data_bytes = blob.download_as_string()
    dict_t = json.loads(json_data_bytes)
    return dict_t
    

def tryGotUnassignedInResponse2(date : str,  session: str, street: None, unassignedJob =None ):
    
    client = storage.Client()
    bucket = client.get_bucket(bucketName)

    fullDataFrame = pd.read_csv(gStorage)
    fullDataFrame = fullDataFrame.loc[(fullDataFrame['Courier Type'] != "NON_GCA5") ]
    #initial id column
    if 'id' not in fullDataFrame .columns:
        fullDataFrame["id"] = fullDataFrame.index+1
    
    # fullDataFrame = pd.read_csv(csvPath)
    if(~(street != street)):
        fullDataFrame, newAwbBooking = addJob(fullDataFrame, date, session, street)

    courierAndZip = fullDataFrame[["Courier id", "zip"]]
    courierAndZip = courierAndZip[fullDataFrame['zip'].notna()]
    courierAndZip = courierAndZip[courierAndZip["zip"].astype(str).str.isdigit()] 
    zipSet = courierAndZip.groupby(["Courier id"])["zip"].aggregate(lambda x: set(map(int, x)))
    partialDataFrame = fullDataFrame
    partialDataFrame = partialDataFrame.loc[partialDataFrame['Act Dt'] == int(date)]
    deliveryListRoute, fullDataFrame = getDeliveryRoute(partialDataFrame, fullDataFrame, session)
    jobsList, vehicleList = createJobsAndVehiclesList(deliveryListRoute, getTimeWindowWithSession(session), zipSet)
    
    dict_t = createDictionaryObjectJobsVehicles(jobsList,vehicleList)
    print(len(deliveryListRoute))
#     print(deliveryListRoute)
#     print( dict_t)
#     print(vehicleList[0].time_window)

    content = json.dumps(dict_t, cls=NpEncoder) 
    
    blob = bucket.blob(getInputeForResponseFileName(date,session))

    blob.upload_from_string(content, "application/json")

    headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
    r = requests.post(url, data=content, headers=headers)    
    
    if (r.status_code != 200) :
        print ("Error request code : ")
        print(r.status_code)
        print(r.content)
#         print(dict_t)
    
    else:
        blob = bucket.blob(getResponseFileName(date, session))

        blob.upload_from_string(r.content, "application/json")

    #     #update the added job to csv
        newJobDataFrame = fullDataFrame.loc[(fullDataFrame["awb_booking"] == newAwbBooking)]

    #     #temp fix
        fullDataFrame.at[newJobDataFrame.index[0], "Courier Type"] = "NON_GCA5"

        string = fullDataFrame.to_csv(None, index=False)

        blob = bucket.blob("3.csv")

        blob.upload_from_string(string, "application/vnd.ms-excel")

        dict_t = json.loads(r.content)
        dict_t["extra"] = {}

        dict_t["extra"]["awb_booking"] = newAwbBooking

        responseDict = gotUnssigned(dict_t)

#     print(dict_t)
    # print(responseDict == [])#
#     print(content)
    return dict_t

# %%
test_dict_t = tryGotUnassignedInResponse2(date,session,street)
# Out:
# trigger no cloud geocode . . .
# capacity : [13]
# 14

# %%
test_dict_t
# Out:
# {'code': 0,
#  'summary': {'cost': 66869,
#   'unassigned': 0,
#   'delivery': [158],
#   'amount': [158],
#   'pickup': [0],
#   'service': 47400,
#   'duration': 66869,
#   'waiting_time': 0,
#   'distance': 953583,
#   'computing_times': {'loading': 114, 'solving': 6072, 'routing': 56}},
#  'unassigned': [],
#  'routes': [{'vehicle': 447,
#    'cost': 4048,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 4048,
#    'waiting_time': 0,
#    'distance': 43559,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.9168708, 2.7047421],
#      'job': 7589,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 31844,
#      'duration': 344,
#      'distance': 5841},
#     {'type': 'job',
#      'location': [101.9159438, 2.7010402],
#      'job': 574,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 32223,
#      'duration': 423,
#      'distance': 6389},
#     {'type': 'job',
#      'location': [101.9175238, 2.6953908],
#      'job': 575,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 32644,
#      'duration': 544,
#      'distance': 7372},
#     {'type': 'job',
#      'location': [101.9236249, 2.688915],
#      'job': 578,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 33162,
#      'duration': 762,
#      'distance': 9275},
#     {'type': 'job',
#      'location': [101.9266453, 2.6848554],
#      'job': 579,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 33669,
#      'duration': 969,
#      'distance': 10476},
#     {'type': 'job',
#      'location': [101.8980233, 2.6777029],
#      'job': 587,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 34411,
#      'duration': 1411,
#      'distance': 15607},
#     {'type': 'job',
#      'location': [101.8764521, 2.6598506],
#      'job': 586,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 35292,
#      'duration': 1992,
#      'distance': 21417},
#     {'type': 'job',
#      'location': [101.8569069, 2.6724919],
#      'job': 585,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 36080,
#      'duration': 2480,
#      'distance': 24863},
#     {'type': 'job',
#      'location': [101.9085892, 2.6872418999999996],
#      'job': 580,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 37126,
#      'duration': 3226,
#      'distance': 33752},
#     {'type': 'job',
#      'location': [101.9111368, 2.691144],
#      'job': 581,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 37542,
#      'duration': 3342,
#      'distance': 34505},
#     {'type': 'job',
#      'location': [101.9107812, 2.6940046000000004],
#      'job': 582,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival': 38059,
#      'duration': 3559,
#      'distance': 36299},
#     {'type': 'job',
#      'location': [101.9123992, 2.7015334],
#      'job': 583,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [1],
#      'arrival': 38491,
#      'duration': 3691,
#      'distance': 37531},
#     {'type': 'job',
#      'location': [101.9112658, 2.7028797000000004],
#      'job': 584,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [0],
#      'arrival': 38822,
#      'duration': 3722,
#      'distance': 37803},
#     {'type': 'end',
#      'location': [101.9381, 2.7297],
#      'load': [0],
#      'arrival': 39448,
#      'duration': 4048,
#      'distance': 43559}],
#    'geometry': 'ictOkxdmRa@k@B?R_@P]DIPq@H[HY@EJURGVGp@IvCg@xA[^GbCc@tAUXtA@Dl@rCXvAPdAb@bCTlAlDq@JC|Co@TEhB[lB[tCc@NEp@ORCBNNt@DXX`B@LDb@@b@?\\Ar@Er@yBzLy@vD{AtH{AtHk@lCc@nCWfDABKtA?B?J?BAlA?H@fA@x@LrAHr@Pr@Tt@Z|@LVTh@f@z@DFb@p@xEjDjBlAxA~@`@X`BhAFDxAdAz@l@lAdBtDlFNTFJj@bAr@lA\\p@FJh@dAP^R^JTx@dAr@~@hB~BRVr@`ApAdB|@nAl@r@t@v@bAf@`@T`@N`ErAf@BNCJGVWh@yA`@g@XeAPkAT{BHw@?yB?k@@kBbGAJ?lHA`IA~DKz@?NAv@E^C`@C~AMVARAnEW`@CdAERAb@ENtD@RBl@NFrA@@v@Aw@I]OYOA}@@ASOuDzE[nAI|CSb@EnBMjAITCH?|AOXCf@E`CO^?xA@b@@hBBL@El@^F_@GDm@pADh@Cr@?H?dBDV@j@@p@?p@BlA@R@f@@xABjBDJ}CTgB\\mB|@oB|BgCnCqEJQnDmC~@{@vC{Dh@sALe@@Q_BkAqCwB}@lAfAv@j@b@H\\}B~Cq@~@p@_A|B_DI]k@c@gAw@|@mAmDmC_@UQMFO^s@FMLInCmDLQb@g@VY\\GXCjEfBvAt@xAv@jG~
@cB{@c@Qo@Wi@Oe@MSE{Bi@}B_@eAS]CDYJi@z@gF@M}@g@cC_Az@eGgBYFs@Gr@eB_@_Ek@m@GeA@i@?e@ESENcATwAoAC{@A{@Cw@A}@AA}DAoB@nB@|D|@@v@@z@Bz@@nABRyA`AqG{Dg@I?oG??hDBpI@D?X_@Bk@Hc@XwCdBcBfAy@p@KQIm@i@_DGk@KmAAqADc@_@@S@^eCFq@@ALmAL}A@OEcCf@IAQQw@AC]{@w@sAkAkBEGy@KODc@Pk@P]H_AL{@B}@AkAA[AS@c@Fa@Lu@Vw@d@WL{@ZUJgAd@s@Z[P]LiAVYF}@F_AAeBA{A?oFAY`DIt@C^MdBQ?uAS_@GyA[yCi@kHKwGDiBAeAIm@EMEMCOIc@Qa@SmCeAc@MaF_BcA_@UI}@Y}DoAm@Y[Sy@s@_@]O[m@}@e@u@i@w@_AyAkA}AeB}Bu@aAOSW]OYGMYg@EGw@uAe@aAq@oAu@qAqGaJuCsB{AgAqFiD{EwDm@_A[m@IQ[k@Wg@Sq@Sw@Mu@Gs@I_AEq@Cy@Au@?M@}@?O?GDg@NaBL_BfAyFhA}FRaATiAh@sC@Ij@kCl@wCRkALw@dAmFXkBBg@?q@AYAYIs@U_BGUOs@AQS_A_A}E}E`AeBZ_@Fi@Jq@LoDr@eDn@qDj@oDj@}@PgARIBgBZa@B_@BS?{@@O?M?Q?SA_@?UQKS?QJWd@SFCNGHGJI`@j@'},
#   {'vehicle': 472,
#    'cost': 7396,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 7396,
#    'waiting_time': 0,
#    'distance': 100751,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.81890909999998, 2.5597087000000003],
#      'job': 598,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 32759,
#      'duration': 1259,
#      'distance': 26751},
#     {'type': 'job',
#      'location': [101.7951277, 2.5365662],
#      'job': 607,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 33326,
#      'duration': 1526,
#      'distance': 31211},
#     {'type': 'job',
#      'location': [101.8100308, 2.528193],
#      'job': 599,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 33901,
#      'duration': 1801,
#      'distance': 34136},
#     {'type': 'job',
#      'location': [101.8078476, 2.5274004],
#      'job': 606,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 34268,
#      'duration': 1868,
#      'distance': 34416},
#     {'type': 'job',
#      'location': [101.8078476, 2.5274004],
#      'job': 605,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 34568,
#      'duration': 1868,
#      'distance': 34416},
#     {'type': 'job',
#      'location': [101.821529, 2.5287102999999997],
#      'job': 601,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 35094,
#      'duration': 2094,
#      'distance': 36482},
#     {'type': 'job',
#      'location': [101.8215922, 2.5288214],
#      'job': 600,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 35395,
#      'duration': 2095,
#      'distance': 36492},
#     {'type': 'job',
#      'location': [101.8233392, 2.5294317000000004],
#      'job': 604,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 35713,
#      'duration': 2113,
#      'distance': 36648},
#     {'type': 'job',
#      'location': [101.8214778, 2.5287526],
#      'job': 602,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 36032,
#      'duration': 2132,
#      'distance': 36819},
#     {'type': 'job',
#      'location': [101.83174, 2.5220548],
#      'job': 603,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 36769,
#      'duration': 2569,
#      'distance': 40758},
#     {'type': 'job',
#      'location': [101.8969767, 2.5285629000000003],
#      'job': 7587,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival': 38871,
#      'duration': 4371,
#      'distance': 57867},
#     {'type': 'job',
#      'location': [101.8969767, 2.5285629000000003],
#      'job': 7588,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [1],
#      'arrival': 39171,
#      'duration': 4371,
#      'distance': 57867},
#     {'type': 'job',
#      'location': [101.961776, 2.5870457],
#      'job': 597,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [0],
#      'arrival': 41370,
#      'duration': 6270,
#      'distance': 79156},
#     {'type': 'end',
#      'location': [101.9381, 2.7297],
#      'load': [0],
#      'arrival':
}@lAq@|@]j@oA~Bw@jBc@lA_@`AoAhEYnAOdAGfAC|BFvBb@vDf@`E~@lHJnBAlAGfAM~BOp@UjE@TBfABv@F`@N~@V~@v@`Bx@dA`AnAJN|BtCr@bAr@|AV~@X`AJv@LnB@bBC~@QfBIx@c@|DOlBItBBdA?H@DBL\\dAlAzBbClDf@d@QNo@l@a@b@eCxBc@`@V\\~Am@DCpEsAXBtBpAEP]N}HnC[_@iAaBW]_BpA}@l@WP]TiCbBqFdDaANw@F_@By@Aq@AGASCKAYCoAc@iCq@qGOe@CaDIoAE_AGuAEK?a@A{ATe@FUFcA\\a@PYe@mAcCm@qBI]u@eAUONGn@YfAc@JG|@_@l@WhAg@PEpAm@a@iA?SNs@T]d@Qj@WhE}Ah@Sf@Sz@tBf@pA^bAV\\JJHFpATpCf@D@ZFd@HTJRN@DRf@@FCv@SjAERE~ANz@|@|@\\\\LRXb@V^JTDJPb@ZvAPp@Lp@@JT~B[|FOnC?f@GhD?NBnAHv@Th@\\h@~@xAJTHTFVBX?XAXERGNQh@GNEPFFDH@H?FAHEFEDh@r@X\\dBvBbBxAHFJDJBH?D@FBFFDJ?FK|@DJHHFFNBR@f@H~@L_AMg@ISAOCu@CIAq@CgAVeBd@Qb@KXEZAZF^N\\dAnBTd@R^P\\P\\JTTt@XtA@Dl@rCXvAqDj@oDj@}@PgARIBgBZa@B_@BS?{@@O?M?Q?SA_@?UQKS?QJWd@SFCNGHGJI`@j@'},
#   {'vehicle': 530,
#    'cost': 7072,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 7072,
#    'waiting_time': 0,
#    'distance': 92961,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.7645877, 2.7379765],
#      'job': 473,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 33142,
#      'duration': 1642,
#      'distance': 25633},
#     {'type': 'job',
#      'location': [101.7648662, 2.7324557],
#      'job': 474,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 33670,
#      'duration': 1870,
#      'distance': 27018},
#     {'type': 'job',
#      'location': [101.7606156, 2.7297298999999997],
#      'job': 475,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 34268,
#      'duration': 2168,
#      'distance': 28673},
#     {'type': 'job',
#      'location': [101.7686444, 2.7444721000000003],
#      'job': 477,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 34967,
#      'duration': 2567,
#      'distance': 31822},
#     {'type': 'job',
#      'location': [101.7686444, 2.7444721000000003],
#      'job': 476,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 35267,
#      'duration': 2567,
#      'distance': 31822},
#     {'type': 'job',
#      'location': [101.7319147, 2.7595104],
#      'job': 478,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 36330,
#      'duration': 3330,
#      'distance': 41668},
#     {'type': 'job',
#      'location': [101.8252193, 2.8321692],
#      'job': 660,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 37928,
#      'duration': 4628,
#      'distance': 60154},
#     {'type': 'job',
#      'location': [101.8236054, 2.8319782000000004],
#      'job': 659,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 38308,
#      'duration': 4708,
#      'distance': 60450},
#     {'type': 'job',
#      'location': [101.813504, 2.8333147999999997],
#      'job': 658,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 39088,
#      'duration': 5188,
#      'distance': 62412},
#     {'type': 'job',
#      'location': [101.8095102, 2.8338565],
#      'job': 657,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 39623,
#      'duration': 5423,
#      'distance': 63340},
#     {'type': 'job',
#      'location': [101.8104882, 2.8313881000000003],
#      'job': 656,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival': 40052,
#      'duration': 5552,
#      'distance': 63866},
#     {'type': 'job',
#      'location': [101.8139981, 2.831172],
#      'job': 655,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [1],
#      'arrival': 40446,
#      'duration': 5646,
#      'distance': 64257},
#     {'type': 'job',
#      'location': [101.8139298, 2.8294153],
#      'job': 654,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [0],
#      'arrival':
D@I@ALq@He@RaATsAFq@OuE?]IaCEu@Gq@EIEMSi@e@_AYg@CE{@y@CEUS]Y_A{@QQqAiAkAeA{@w@IICCwAqAYWk@g@CCOMaA}@y@s@_@_@o@i@aA}@}@u@[[][SQ]]WYq@k@QMkBcBCA{@y@_A_AkBeBIKGGoC_CaByAy@s@yDeDYIGCqAgAc@_@eB_Be@e@S[Os@e@wBe@oBc@wB[wA[aBQ{@Mc@ISOYoAsA??w@{@eBmBgBqBuAwA}@cAKKmD}DwDyDwAqAKMoCoCqAsAuBoBo@b@sDnD_Al@_AJ}ABqABOA_AEcCKk@AgHGeIGwDGmBCy@EcFYq@Qs@]QMmJsHcBqA_@[OKWMmBaBvEuF|BqCLKz@i@l@QTGh@EDiAAg@?[pAA@wDAvDqA@?Z@f@EhAVCdB@X?`C@fCDfB?~@@zARb@NZ\\Rh@Jx@BLJbC?DD`DJnH@JJ`IAl@ExCArA?fAO|F?XA`BAz@u@AgBCsBCsACyCGiBA{@A?n@sEE_@PKLCl@Bm@JM^QrED?o@}CEo@@k@TSJEFGFYp@uBtFw@pBMh@B\\Ld@d@x@~@lBm@f@SNxAxByAyBROl@g@~AfC\\l@b@Ph@Al@ODAhA[d@Oz@Yf@M\\_@Nc@@e@?OBiB?i@BoA?SBeABqA?ID}DDuA?QxCFrABrBB?N?OfBBt@@l@@bKN~DJrBd@XJPD]zA{BdGs@tAi ...
#   {'vehicle': 553,
#    'cost': 8389,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 8389,
#    'waiting_time': 0,
#    'distance': 92159,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.7335601, 2.7373791],
#      'job': 479,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 33664,
#      'duration': 2164,
#      'distance': 36972},
#     {'type': 'job',
#      'location': [101.7128872, 2.733902],
#      'job': 487,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 35072,
#      'duration': 3272,
#      'distance': 43382},
#     {'type': 'job',
#      'location': [101.7130376, 2.7353172000000003],
#      'job': 488,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 35377,
#      'duration': 3277,
#      'distance': 43404},
#     {'type': 'job',
#      'location': [101.7227306, 2.7193634],
#      'job': 641,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 36540,
#      'duration': 4140,
#      'distance': 46911},
#     {'type': 'job',
#      'location': [101.7175398, 2.7274787999999996],
#      'job': 481,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 37229,
#      'duration': 4529,
#      'distance': 48483},
#     {'type': 'job',
#      'location': [101.7175398, 2.7274787999999996],
#      'job': 480,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 37529,
#      'duration': 4529,
#      'distance': 48483},
#     {'type': 'job',
#      'location': [101.7157536, 2.7345662],
#      'job': 485,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 38045,
#      'duration': 4745,
#      'distance': 49324},
#     {'type': 'job',
#      'location': [101.715897, 2.7345878],
#      'job': 486,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 38345,
#      'duration': 4745,
#      'distance': 49324},
#     {'type': 'job',
#      'location': [101.7181865, 2.7277228],
#      'job': 482,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 38852,
#      'duration': 4952,
#      'distance': 50156},
#     {'type': 'job',
#      'location': [101.7186104, 2.7294928],
#      'job': 483,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 39265,
#      'duration': 5065,
#      'distance': 50590},
#     {'type': 'job',
#      'location': [101.7254181, 2.7277417],
#      'job': 642,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival': 39818,
#      'duration': 5318,
#      'distance': 51983},
#     {'type': 'job',
#      'location': [101.7253394, 2.7278642000000004],
#      'job': 643,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [1],
#      'arrival':
JIZ}@t@_@b@BXXr@lAPXRCpAu@TOJIfH_E_QyYoDcG_CuCkCiBkBm@qCc@kBKkCH_APkr@rM{L|BsCf@KBgC`@mAVkE|@yDr@}GhBsEpAoBn@iBp@oAf@{Bz@QFO_@e@kAiA}CyBaG{AgEuA}DeBoEq@uAo@qA}B}De@aA[s@Ws@[cAU_AWyAIm@Ck@G{AGwOEaH?e@MmWA}ABmAJkANsANaAR{@ZaA\\cArEqL\\iARgAL_AFw@Bw@?aAC_AK_FK{BOcFeG`AyFv@gALkBNgADeA?qDIeBMcBY}GwA_AQmEg@uAQeDa@a@EW?WDQBUDw@RyAb@wBj@qA\\qAZiB`@cDx@s@V{D`Ag@LuA\\m@J_@DO?W?YCQAo@G}BUc@I]Ku@[kBiAgAk@e@Wk@U]Gi@E{@Ok@AQAK@KkAAs@?gAK}BScB]aBIe@Ak@@e@Fc@`@wAD_@@WMYYOSGQEs@M_AUa@Sk@a@QU]s@CGo@kBYw@GKSUgBkB{@}@c@c@g@i@{@}@eCiCMMMOqFwFUWqGyGo@q@sEaFk@i@KMeBiBiAmAcAqAM]Ea@?kAAyCAyBA}DRyABm@Mm@o@uBQg@}AsCUc@a@gAc@oAI_@Cc@CWKkCAMO{DAa@OoEAIAWC}@BmAV_An@mA^o@Ti@Fk@?mAI_AMo@Y{@Mo@A_APuBH}AEw@I_@Oy@K{@GeB]yACe@Ha@Hm@BOBMHc@?k@E]EOSq@a@sAg@w@a@[e@Q]SQMS]iAwBWg@eAuBc@qAKs@BW@]RcA@m@Kg@M ...
#   {'vehicle': 573,
#    'cost': 6377,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 6377,
#    'waiting_time': 0,
#    'distance': 127404,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.6303122, 2.9369712000000003],
#      'job': 500,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 34059,
#      'duration': 2559,
#      'distance': 58333},
#     {'type': 'job',
#      'location': [101.6312765, 2.9338203999999997],
#      'job': 543,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 34442,
#      'duration': 2642,
#      'distance': 59295},
#     {'type': 'job',
#      'location': [101.6310938, 2.9337042999999996],
#      'job': 544,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 34743,
#      'duration': 2643,
#      'distance': 59316},
#     {'type': 'job',
#      'location': [101.6587418, 2.930482],
#      'job': 508,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 35468,
#      'duration': 3068,
#      'distance': 64233},
#     {'type': 'job',
#      'location': [101.654798, 2.9261923],
#      'job': 513,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 35935,
#      'duration': 3235,
#      'distance': 65347},
#     {'type': 'job',
#      'location': [101.6547707, 2.9261787],
#      'job': 512,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 36236,
#      'duration': 3236,
#      'distance': 65351},
#     {'type': 'job',
#      'location': [101.6543311, 2.9262896],
#      'job': 511,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 36560,
#      'duration': 3260,
#      'distance': 65423},
#     {'type': 'job',
#      'location': [101.6534378, 2.9273702],
#      'job': 503,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 36954,
#      'duration': 3354,
#      'distance': 65898},
#     {'type': 'job',
#      'location': [101.6512835, 2.9259467999999997],
#      'job': 502,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 37453,
#      'duration': 3553,
#      'distance': 67523},
#     {'type': 'job',
#      'location': [101.6513328, 2.9252069],
#      'job': 537,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 37773,
#      'duration': 3573,
#      'distance': 67605},
#     {'type': 'job',
#      'location': [101.651006, 2.9228807999999997],
#      'job': 539,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival':
@pAn@z@f@r@l@x@j@x@^h@v@x@`@h@\\^pAnAv@r@`@b@TXn@|@r@|@HLx@pAt@vAl@hAp@pAd@|@V^V\\VVVVXVd@\\z@f@VFFAPAPBNHJLDN@PCPILKJOFQ@OCOGKKg@?s@BgW|C_KjAwZvDmB\\qA^i@^cAhAeBrDU`AOjAGfAF`@BXlBbILvAdAlEnCfKr@bCdB|FHZtBzKxEhYJl@XRTlAXx@f@r@`@\\b@Ph@Np@Fj@El@Kt@Yb@AfAc@bBw@xNkG`k@sU|FaCvIqDvUuJta@_QvD_BtIqDth@qT|X}NxQqNbIkG`RcSt@w@bN_OvSmOjQ}JpVqNdXqRlZ{XdOyPjFcH~CqEnF{IbCsFzBmI`A{Gh@kFJaKa@{HgA{H{AuGgAiF}@yG_@yFGwFHkEb@wFz@uFl@aDfAgD^kAXu@r@_BdAwBf@{@f@_A~C_FnEiIxB}DjBiEhEoL~BmHnCcMn@uD~AuL`@cF`@{KNyECcDYuTi@aH]{D]_EkBaKoBoJiDkMUm@qAgDaIkQwGsLiHcM{KqTyC{IuB{IkAaIy@uIcCyZi@{EiA_JSyAMkAc@}COmAMq@o@}DwDcUwAkMiAoMw@eQUwMO}YaAqZDsMpAeMpA}FrBcHbHiO`GoKvEcM~H_[lA{FZmBTmB@gACcAMwAM}@SkA?WKe@Cu@Bs@Da@Fg@Ro@l@{@r@k@f@Wp@Sd@G~@Eh@@v@H`AZlAj@|@\\^PNDPDH@F@H@JBdBJ~CMbBOhAStD{@tAa@r@Yl@YbCkA`CmAlF{BhBk@z@OhAQ|AU|AWvEU~CQjCQjCQr ...
#   {'vehicle': 596,
#    'cost': 7643,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 7643,
#    'waiting_time': 0,
#    'distance': 136551,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.6734488, 2.9508196],
#      'job': 506,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 34146,
#      'duration': 2646,
#      'distance': 57831},
#     {'type': 'job',
#      'location': [101.6686791, 2.9504901],
#      'job': 505,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 34764,
#      'duration': 2964,
#      'distance': 60284},
#     {'type': 'job',
#      'location': [101.6666027, 2.945401700000001],
#      'job': 507,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 35337,
#      'duration': 3237,
#      'distance': 62205},
#     {'type': 'job',
#      'location': [101.6542334, 2.9471568],
#      'job': 504,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 35971,
#      'duration': 3571,
#      'distance': 65075},
#     {'type': 'job',
#      'location': [101.659413, 2.9286966],
#      'job': 509,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 36551,
#      'duration': 3851,
#      'distance': 69199},
#     {'type': 'job',
#      'location': [101.6580758, 2.926631],
#      'job': 514,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 36944,
#      'duration': 3944,
#      'distance': 69584},
#     {'type': 'job',
#      'location': [101.6614866, 2.9192826000000003],
#      'job': 510,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 37529,
#      'duration': 4229,
#      'distance': 72090},
#     {'type': 'job',
#      'location': [101.6548106, 2.9129879],
#      'job': 546,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 37998,
#      'duration': 4398,
#      'distance': 73729},
#     {'type': 'job',
#      'location': [101.6568788, 2.9202009],
#      'job': 533,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 38450,
#      'duration': 4550,
#      'distance': 75145},
#     {'type': 'job',
#      'location': [101.6560226, 2.9213404],
#      'job': 536,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 38873,
#      'duration': 4673,
#      'distance': 75812},
#     {'type': 'job',
#      'location': [101.6537416, 2.9211574],
#      'job': 535,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival':
@\\Al@?b@?VAr@Ad@?N?V?h@O|JA|C?LAv@Ap@@bCDh@Bb@Lp@DRX|@V`AHZN^oJ~CkFfBe@NQDCEEIOc@wDeKmCyGSISEWBC@EBk@d@}ApAi@f@{@r@[R[NUHc@FgALc@F_Eh@yBZSB_@DwC`@aCXIe@OaA[}A?UMkAMkAAM?OqBLgBJs@DU@a@@S@?LMJWHEFAF?JDVFJDFNFOGEGGKEW?K@GDGVILK?MYBG?w@DJx@TlBX|BNvANbAkBV]DBTx@jCZ~@Vz@b@tAn@tBNd@Pn@NnA@nBGrBCzA?VALAbAC~AAh@C|AATCPIFaEMo@?UAk@?U?e@?K?k@@K?KIIGe@g@W]SOGAIBIFWXo@f@@L@TCd@CJGJUb@ABa@l@OXGNELIXWfBi@dAKP[f@g@l@QX{@bAo@p@[n@Q`@Wp@CLGh@KXMPCFIJQTEDo@x@MXMZs@~AwAhC}@lAq@|@]j@oA~Bw@jBc@lA_@`AoAhEYnAOdAGfAC|BFvBb@vDf@`E~@lHJnBAlAGfAM~BOp@UjE@TBfABv@F`@N~@V~@v@`Bx@dA`AnAJN|BtCr@bAr@|AV~@X`AJv@LnB@bBC~@QfBIx@c@|DOlBItBBdA?H@DBL\\dAlAzBbClDf@d@dC|AlBfAPHjAp@l@\\j@^f@T\\HVBb@@\\@Z?b@ATCfDYp@En@?r@@^DXH^J^RVN|CjDtAdBRVn@x@JJ`CvCrBjCt@~@BDPT\\n@INg@lAMXGTEZABw@|BGRGNSn@i@~Ai@|AKXELmB`Gg@rAc@bAw@rAaAdBABs@hAGHKPk@~@y@rA}A`C{C~EGHk@z@W\\cBbCMNML_@Tu@N_BXYFeBXyBb@[D}E`AeBZ_@Fi@Jq@LoDr@eDn@qDj@oDj@}@PgARIBgBZa@B_@BS?{@@O?M?Q?SA_@?UQKS?QJWd@SFCNGHGJI`@j@'},
#   {'vehicle': 651,
#    'cost': 2180,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 2180,
#    'waiting_time': 0,
#    'distance': 28033,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [102.0068182, 2.6767461],
#      'job': 707,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 32257,
#      'duration': 757,
#      'distance': 12093},
#     {'type': 'job',
#      'location': [102.004397, 2.6783005],
#      'job': 709,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 32600,
#      'duration': 800,
#      'distance': 12359},
#     {'type': 'job',
#      'location': [102.0047567, 2.6781035],
#      'job': 710,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 32902,
#      'duration': 802,
#      'distance': 12376},
#     {'type': 'job',
#      'location': [102.0134265, 2.6782008],
#      'job': 711,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 33364,
#      'duration': 964,
#      'distance': 13493},
#     {'type': 'job',
#      'location': [102.0096989, 2.6750292],
#      'job': 704,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 33817,
#      'duration': 1117,
#      'distance': 14360},
#     {'type': 'job',
#      'location': [102.0097272, 2.6749572999999995],
#      'job': 703,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 34119,
#      'duration': 1119,
#      'distance': 14366},
#     {'type': 'job',
#      'location': [102.0097252, 2.6749998],
#      'job': 706,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 34420,
#      'duration': 1120,
#      'distance': 14370},
#     {'type': 'job',
#      'location': [102.0097252, 2.6749998],
#      'job': 705,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 34720,
#      'duration': 1120,
#      'distance': 14370},
#     {'type': 'job',
#      'location': [102.0078898, 2.6743897999999997],
#      'job': 702,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 35086,
#      'duration': 1186,
#      'distance': 14762},
#     {'type': 'job',
#      'location': [102.0056584, 2.6761369],
#      'job': 708,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival':
iDvAoChAgAf@OHcAh@a@T_BxAgAfB{A|By@dACDc@f@Y\\c@d@MLkEtEcAbAwAlAeA~@YXYXg@d@IHk@n@YVc@^c@VGBUJ_@JeANwARK@e@JEBa@PWRC@cAr@WPQLQPMNKPILSd@i@rAA@KTABw@|BGRGNSn@i@~Ai@|AKXELmB`Gg@rAc@bAw@rAaAdBABs@hAGHKPk@~@y@rA}A`C{C~EGHk@z@W\\cBbCMNML_@Tu@N_BXYFeBXyBb@[D}E`AeBZ_@Fi@Jq@LoDr@eDn@qDj@oDj@}@PgARIBgBZa@B_@BS?{@@O?M?Q?SA_@?UQKS?QJWd@SFCNGHGJI`@j@'},
#   {'vehicle': 697,
#    'cost': 5097,
#    'delivery': [13],
#    'amount': [13],
#    'pickup': [0],
#    'service': 3900,
#    'duration': 5097,
#    'waiting_time': 0,
#    'distance': 72326,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [13],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.7990082, 2.8546912],
#      'job': 669,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [12],
#      'arrival': 32926,
#      'duration': 1426,
#      'distance': 29158},
#     {'type': 'job',
#      'location': [101.7932446, 2.8588169],
#      'job': 668,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [11],
#      'arrival': 33480,
#      'duration': 1680,
#      'distance': 30186},
#     {'type': 'job',
#      'location': [101.8059716, 2.8616945],
#      'job': 664,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [10],
#      'arrival': 34189,
#      'duration': 2089,
#      'distance': 32245},
#     {'type': 'job',
#      'location': [101.8028029, 2.8654803],
#      'job': 667,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [9],
#      'arrival': 34673,
#      'duration': 2273,
#      'distance': 33140},
#     {'type': 'job',
#      'location': [101.8014511, 2.8676182999999997],
#      'job': 666,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [8],
#      'arrival': 35077,
#      'duration': 2377,
#      'distance': 33538},
#     {'type': 'job',
#      'location': [101.8069718, 2.8672274],
#      'job': 665,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [7],
#      'arrival': 35518,
#      'duration': 2518,
#      'distance': 34248},
#     {'type': 'job',
#      'location': [101.8122454, 2.8666658],
#      'job': 662,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [6],
#      'arrival': 35927,
#      'duration': 2627,
#      'distance': 34928},
#     {'type': 'job',
#      'location': [101.8115265, 2.8623554],
#      'job': 663,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [5],
#      'arrival': 36389,
#      'duration': 2789,
#      'distance': 35557},
#     {'type': 'job',
#      'location': [101.8057304, 2.8503773999999997],
#      'job': 661,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [4],
#      'arrival': 37082,
#      'duration': 3182,
#      'distance': 38832},
#     {'type': 'job',
#      'location': [101.8074542, 2.8407797],
#      'job': 670,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [3],
#      'arrival': 37586,
#      'duration': 3386,
#      'distance': 40214},
#     {'type': 'job',
#      'location': [101.8061199, 2.8176509999999997],
#      'job': 652,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival': 38204,
#      'duration': 3704,
#      'distance': 43600},
#     {'type': 'job',
#      'location': [101.8054923, 2.8216026000000003],
#      'job': 653,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [1],
#      'arrival': 38594,
#      'duration': 3794,
#      'distance': 44105},
#     {'type': 'job',
#      'location': [101.8084976, 2.8274357999999995],
#      'job': 644,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [0],
#      'arrival': 38974,
#      'duration': 3874,
#      'distance': 44944},
#     {'type': 'end',
#      'location': [101.9381, 2.7297],
#      'load': [0],
#      'arrival': 40497,
#      'duration': 5097,
#      'distance': 72326}],
#    'geometry': 'ictOkxdmRa@k@B?R_@P]DIPq@H[HY@EJURGVGp@IvCg@xA[^GbCc@tAUXtA@Dl@rCXvAPdAb@bCTlAlDq@JC|Co@TEhB[lB[tCc@NEp@ORCBNNt@DXX`B@LDb@@b@?\\Ar@Er@yBzLy@vD{AtH{AtHk@lCc@nCWfDABKtA?B?J?BAlA?H@fA@x@LrAHr@Pr@Tt@Z|@LVTh@f@z@DFb@p@xEjDjBlAxA~@`@X`BhAFDxAdAz@l@lAdBtDlFNTFJj@bAr@lA\\p@FJh@dAP^R^JTx@dAr@~@hB~BRV\\NRDN@LCbBgAbAy@FEFGVSPKNQHKHMDO@K@M?MAOEQGOIIIGMIOESAM?M@OBMDa@R_@X}BnBq@PmBtB{CrD_CvCyBlDw@`BaDjHq@nAqArDcCxGkJlWgBtEiA~BsA~CyAhC{AvCgDlG{BhDoF~H}IrKmFlFsFpFiIbH{[fT{AfAw@j@_A~@aBfBc@l@m@|@aAhAiAfBaAjB}@tBoA|Di@xB_@pBWtBi@jF_AzIEb@]tDEZe@bEo@`E{AvHaBtFe@rAUh@Wj@e@bAox@fzAa@x@cE~IoAhD]|@iAzCmEjPG
@QH]w@s@yAaDgD{@{@sAsAmCmCkBiAg@[OKHOPJpCjB`FzExE~EZf@Tf@P\\Xl@\\jADtA@bB@zD@fCWHcCCs@?gB@yD?{A@kCE}AEuBUoDo@yEy@cDi@iAIyADkARsAd@m@\\e@`@g@l@i@~@Y`AO|@Ex@BfALdA^pAl@bBv@hBz@rB^z@HPb@|AjAhE`@nBX|@b@fAd@lAz@lAdAjAn@j@v@b@v@ThAZdAJbAAlAUp@Un@UTOfAw@fByAfB{AlAcAfGoFbJgJ~FwH~CiEfBiCv@aAr@{@~@y@`A{@jDoBtEqBtGuB~GwBdC_AlBcAtBuAnBgBhAiA`@a@lAiApAqA~GgGtGuDvFsBjHiBjGw@tIGbiA`BrKFbBDp@?r@AjEKtE_@vEg@`LmBrA[rAa@~CgAxImD`IeEjFqD|AgAbHsHfGuH`Zg`@jCkDt@aA|ByCt@cAHKlLoOvJeNd@u@Vi@P]NYhC{FvA_Dn@{Af@{AjAyDfAyD\\cBXmANw@Jw@xJqv@~AmKbHiVxAiDdGqMnx@}zAv@cBv@yBp@sBl@yBx@kDn@iDj@wDN{ANyAVkCHs@v@}HRoBt@sGb@iCb@iBj@wBl@cBbA_CpAaCjByCl@y@p@w@fBkBbB{A|AiAz\\aUxHmGxFmFzEcFpHcJ`HoJvByDlAwBbCmElCcFpBoEhAcCpBqFvG{Qn@iB|E{Mz@iBpDyH^s@To@nAuBp@uAb@{@N_@P[z@kAVg@@CNg@J[@]AQEWQs@EUAK?KYg@EGw@uAe@aAq@oAu@qAqGaJuCsB{AgAqFiD{EwDm@_A[m@IQ[k@Wg@Sq@Sw@Mu@Gs@I_AEq@Cy@Au@?M@}@?O?GDg@NaBL_BfAyFhA}FRaATiAh@sC@Ij@kCl@wCRkALw@dAmFXkBBg@?q@AYAYIs@U_BGUOs@AQS_A_A}E}E`AeBZ_@Fi@Jq@LoDr@eDn@qDj@oDj@}@PgARIBgBZa@B_@BS?{@@O?M?Q?SA_@?UQKS?QJWd@SFCNGHGJI`@j@'},
#   {'vehicle': 729,
#    'cost': 218,
#    'delivery': [3],
#    'amount': [3],
#    'pickup': [0],
#    'service': 900,
#    'duration': 218,
#    'waiting_time': 0,
#    'distance': 2200,
#    'steps': [{'type': 'start',
#      'location': [101.9381, 2.7297],
#      'load': [3],
#      'arrival': 31500,
#      'duration': 0,
#      'distance': 0},
#     {'type': 'job',
#      'location': [101.9390577, 2.7259512000000004],
#      'job': 557,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [2],
#      'arrival': 31548,
#      'duration': 48,
#      'distance': 646},
#     {'type': 'job',
#      'location': [101.937436, 2.7246962000000003],
#      'job': 555,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [1],
#      'arrival': 31892,
#      'duration': 92,
#      'distance': 976},
#     {'type': 'job',
#      'location': [101.938135, 2.7284237],
#      'job': 556,
#      'service': 300,
#      'waiting_time': 0,
#      'load': [0],
#      'arrival': 32240,
#      'duration': 140,
#      'distance': 1535},
#     {'type': 'end',
#      'location': [101.9381, 2.7297],
#      'load': [0],
#      'arrival': 32618,
#      'duration': 218,
#      'distance': 2200}],
#    'geometry': 'ictOkxdmRa@k@B?R_@P]DIPq@H[HY@EJURGVGp@IvCg@xA[^GbCc@tAUXtA@Dl@rCNCOBXvAPdAb@bCTlAlDq@CKS_Ae@_CUiAeDn@qDj@oDj@}@PgARMm@YwAGa@fCe@BHRjATpA}@PgARIBgBZa@B_@BS?{@@O?M?Q?SA_@?UQKS?QJWd@SFCNGHGJI`@j@'}],
#  'extra': {'awb_booking': 'm_7589'}}

# %%
fullDataFrame = pd.read_csv("id3.csv")
counterJob = 0
# test = json.loads(test_dict_t)
routesIDs = []
route = []
for routes in test_dict_t["routes"]:
    route = []
    route.append(routes["vehicle"])
    for indexStep, step in enumerate( routes["steps"], start = 1):
        if(step["type"] == "job"):
#             jobIDs.append(step["job"])
            route.append(step["job"])
            counterJob+=1
    routesIDs.append(route)
print(counterJob)
fullDataFrame = pd.read_csv("id3.csv")
# mask = (fullDataFrame['id'].isin(ids[0]))
# partialDataFrame = fullDataFrame.loc[fullDataFrame['id'].isin(ids[0])]
routesIDs
# Out:
# 158
# [[447, 7589, 574, 575, 578, 579, 587, 586, 585, 580, 581, 582, 583, 584],
#  [472, 598, 607, 599, 606, 605, 601, 600, 604, 602, 603, 7587, 7588, 597],
#  [499, 449, 448, 554, 577, 576, 561, 560, 559, 452, 450, 451, 558],
#  [530, 473, 474, 475, 477, 476, 478, 660, 659, 658, 657, 656, 655, 654],
#  [553, 479, 487, 488, 641, 481, 480, 485, 486, 482, 483, 642, 643, 484],
#  [573, 500, 543, 544, 508, 513, 512, 511, 503, 502, 537, 539, 538, 501],
#  [596, 506, 505, 507, 504, 509, 514, 510, 546, 533, 536, 535, 534, 547],
#  [618, 541, 542, 540, 532, 545, 531, 627, 628, 626, 625, 624, 623, 629],
#  [622, 712, 751, 752, 753, 750, 749, 748, 747, 698, 731, 732, 746, 730],
#  [640, 745, 743, 742, 741, 740, 738, 737, 739, 736, 735, 734, 733, 744],
#  [651, 707, 709, 710, 711, 704, 703, 706, 705, 702, 708, 701, 700, 699],
#  [697, 669, 668, 664, 667, 666, 665, 662, 663, 661, 670, 652, 653, 644],
#  [729, 557, 555, 556]]

# %%
len(routesIDs)
# Out:
# 13

# %%
counter = 1
routesIDs = []
route = []
for routes in test_dict_t["routes"]:
    df = pd.DataFrame()
    vehicleInformation = fullDataFrame.loc[fullDataFrame['id'] == routes["vehicle"]]
    actCkptCode = vehicleInformation["Act Ckpt Code"].values[0]
    vehicleInformation['id'] = vehicleInformation['id'].astype("int")
    vehicleInformation['id'] = vehicleInformation['id'].astype("str")

    date = vehicleInformation["Act Dt"].values[0]
    name = vehicleInformation["Courier id"].values[0]
    routes["steps"][0]["name"] = vehicleInformation["Courier id"].values[0]
    for indexStep, step in enumerate( routes["steps"], start = 1):
        if(step["type"] == "start" or step["type"] == "end"):
            startingInformation = vehicleInformation.copy()
            startingInformation.at[startingInformation.index[0], "Act Tm"] = getTime24hour(step["arrival"])
            if(step["type"] == "end"):
#                 startingInformation.at[startingInformation.index[0], "id"] = str(startingInformation["id"].values[0]) + "arrvd"
                startingInformation.at[startingInformation.index[0], "Act Ckpt Code"] = "ARRVD"
            if(actCkptCode == "DEPAR"):
                startingInformation.at[startingInformation.index[0], "id"] = str(startingInformation["id"].values[0]) + "arrvd"
            elif(actCkptCode == "ARRVD"):
                startingInformation.at[startingInformation.index[0], "id"] = str(startingInformation["id"].values[0]) + "depart"
            else:
                print("unprepare sitaution 3")
                print("actCkptCode : " + actCkptCode)
            df = df.append(startingInformation)
        elif(step["type"] == "job"):
            jobInformation = fullDataFrame.loc[fullDataFrame['id'] == step["job"]]
            if(jobInformation["Street"].values[0] == jobInformation["Street"].values[0]):
                string = jobInformation["Street"].values[0]
                description = re.sub('\s+', ' ', string)
                step["description"] = description

            else:
                step["description"] = "Street is blank"

            new = pd.DataFrame({'PUD Svc Area': [vehicleInformation["PUD Svc Area"].values[0]], 
                     'PUD Fac': [vehicleInformation["PUD Fac"].values[0]],
                     'PUD Rte': [vehicleInformation["PUD Rte"].values[0]],          
                     'PUD Cycle': [vehicleInformation["PUD Cycle"].values[0]],
                      'Courier id':[vehicleInformation["Courier id"].values[0]],
                      'Courier Type':  [vehicleInformation["Courier Type"].values[0]],
                      'Customer Name': [jobInformation["Customer Name"].values[0]],
                      'Street': [jobInformation["Street"].values[0]],
                      'zip': [jobInformation["zip"].values[0]],
                      'City': [jobInformation["City"].values[0]],
                      'Act Dt': [jobInformation["Act Dt"].values[0]],
                      'Act Base': [jobInformation["Act Base"].values[0]],
                      'Delivery Type': [jobInformation["Delivery Type"].values[0]],
                      'Pickup Type': [jobInformation["Pickup Type"].values[0]],
                      'Prod Grp': [jobInformation["Prod Grp"].values[0]],
                      'Prod Code': [jobInformation["Prod Code"].values[0]],
                      'ShpCnt': [jobInformation["ShpCnt"].values[0]],
                      'Pallets Pcs': [jobInformation["Pallets Pcs"].values[0]],
                      'Parcel Pcs': [jobInformation["Parcel Pcs"].values[0]],
                      'Total Pcs': [jobInformation["Total Pcs"].values[0]],
                      'Weight': [jobInformation["Weight"].values[0]],
                      'AR dtm': [jobInformation["AR dtm"].values[0]],
                      'Act Tm': [getTime24hour(step["arrival"])],
                      'Open': [jobInformation["Open"].values[0]],
                      'Closed': [jobInformation["Closed"].values[0]],
                      'lat':  [step["location"][1]],
                      'lgtd':  [step["location"][0]],
                      'awb_booking': [jobInformation["awb_booking"].values[0]],
                      'Act Ckpt Code': [jobInformation["Act Ckpt Code"].values[0]],
                      'PuD Type': [jobInformation["PuD Type"].values[0]],
                      'Stop Code':  [jobInformation["Stop Code"].values[0]],
                     'MarkerColor':  [jobInformation["MarkerColor"].values[0]], 
                     'id' : [str(step["job"])],
                               })
            df = df.append(new)
        else:
            print("unprepare situation 1")
     #last record = end
    timeIntervalMorning = getTimeWindowWithSession("m")
    timeIntervalAfternoon = getTimeWindowWithSession("a")
#     session = "aaa"
#     getMiliSec(x["Act Tm"]) > getMiliSec("14:00:00") ) & (getMiliSec(x["Act Tm"]) < getMiliSec("23:59:00")  
#     print(getMiliSec(df.iloc[-1]["Act Tm"]))
#     print(getMiliSec(timeIntervalMorning[0]))
#     print(type(getMiliSec(timeIntervalMorning[0])))
                                                          
#     if(getMiliSec(df.iloc[-1]["Act Tm"]) > timeIntervalMorning[0] and getMiliSec(df.iloc[-1]["Act Tm"]) <= timeIntervalMorning[1]):
#         session = "m"
#         print("afternoon")
#     elif(getMiliSec(df.iloc[-1]["Act Tm"]) > timeIntervalAfternoon[0] and getMiliSec(df.iloc[-1]["Act Tm"]) <= timeIntervalAfternoon[1]):
#         session = "a"
#         print("morning")
#     else:
#         print("unprepare situation 2")
    
    df.to_csv("routes/"+ str(date) + "/" +session  + "/" + str(name) + ".csv", index=False)
    counter+=1
df
# Out:
# C:\Users\lun\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lun\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#     PUD Svc Area PUD Fac PUD Rte PUD Cycle Courier id Courier Type  \
# 446          KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 0            KUL     EAC    ACA1         B   rafinord  DHL Courier
# 446          KUL     EAC    ACA1         B   rafinord  DHL Courier
#
#                            Customer Name  \
# 446                                  NaN
# 0                                   name
# 0    BAHAU CIGARETTE DISTRIBUTORS SDN BH
# 0                     COMBI-PACK SDN BHD
# 0      UNIC TECHNOLOGY MALAYSIA SDN BHD.
# 0           FUTURE TECH TRADINGM SDN BHD
# 0            DHL EXPRESS M SDN BHD - EAC
# 0                MRS NURZULAILA ZULKIFLI
# 0                        THE X01 PROJECT
# 0        MOHAMAD KHAIRI HAIZAD KAMARUDIN
# 0                             AU PARFUMS
# 0         EMERSON ELECTRIC M SDN BHD-NDS
# 0               THUNDER MATCH TECHNOLOGY
# 0                             AU PARFUMS
# 446                                  NaN
#
#                                                 Street    zip      City  ...  \
# 446                                                NaN    NaN       NaN  ...
# 0    Jalan Rumbia, Kampung Seberang Paya, 11900 Bay...  11111       123  ...
# 0    WAREHOUSE NO. 1, JALAN HARUAN 1,\nOAKLAND INDU...  70300  SEREMBAN  ...
# 0    NO 277 JALAN HARUAN 1\nOAKLAND INDUSTRIAL PARK...  70300  SEREMBAN  ...
# 0    NO;52,JALAN S2 C2,\nGREEN TECHNOLOGY PARK,\nSE...  70300  SEREMBAN  ...
# 0    NO247,JALAN S2-C11,GREEN TECHNOLOGY\nPARK,7030...  70300  SEREMBAN  ...
# 0    PT NO 13757 JALAN HARUAN 1\nOAKLAND INDUSTRIAL...  70200  SEREMBAN  ...
# 0                        NO1773 JALAN NUSARI 7/8\n.\n.  71950  SEREMBAN  ...
# 0       NO 705,\nJALAN HIJAYU 3/19, HIJAYU 3\nSEREMBAN  71950  SEREMBAN  ...
# 0        387 CITY HOMES ACACIA\nJALAN S2 D14\nSEREMBAN  70300  SEREMBAN  ...
# 0    242, JALAN S2 D3, CITY HOMES, SEREM\n70300 SER...  70300  SEREMBAN  ...
# 0    C/O FRISBERG AUTOMATION\n223-1, JALAN S2 B10,\...  70300  SEREMBAN  ...
# 0    LOT F36 1ST FLOOR, JUSCO SEREMBAN 2\nSHOPPING ...  70300  SEREMBAN  ...
# 0    242, JALAN S2 D3, CITY HOMES, SEREM\n70300 SER...  70300  SEREMBAN  ...
# 446                                                NaN    NaN       NaN  ...
#
#          Open    Closed       lat        lgtd awb_booking Act Ckpt Code  \
# 446       NaN     23:59  2.704989  101.916748         NaN         DEPAR
# 0    00:00:00  23:59:00  2.704742  101.916871      m_7589            OK
# 0         NaN     23:59  2.701040  101.915944  5585029914            OK
# 0         NaN     23:59  2.695391  101.917524  1220489255            OK
# 0         NaN     23:59  2.688915  101.923625  5585029380            OK
# 0         NaN     23:59  2.684855  101.926645  2991443486            OK
# 0         NaN     23:59  2.677703  101.898023  7432864740            OK
# 0         NaN     23:59  2.659851  101.876452  6445983751            OK
# 0         NaN     23:59  2.672492  101.856907  9196467696            OK
# 0         NaN     23:59  2.687242  101.908589  9196008500            OK
# 0        9:00     15:00  2.691144  101.911137  9904586941            PU
# 0         NaN     23:59  2.694005  101.910781  9629777614            OK
# 0         NaN     23:59  2.701533  101.912399  2283278944            OK
# 0        9:00     15:00  2.702880  101.911266  9904599095            PU
# 446       NaN     23:59  2.704989  101.916748         NaN         ARRVD
#
#      PuD Type  Stop Code  MarkerColor        id
# 446       NaN        NaN          NaN  447arrvd
# 0     pudType        NaN          NaN      7589
# 0          DL        1.0          NaN       574
# 0          DL        2.0          NaN       575
# 0          DL        5.0          NaN       578
# 0          DL        6.0          NaN       579
# 0          DL       12.0          NaN       587
# 0          DL       11.0          NaN       586
# 0          DL       10.0          NaN       585
# 0          DL        7.0          NaN       580
# 0          PU        1.0          NaN       581
# 0          DL        8.0          NaN       582
# 0          DL        9.0          NaN       583
# 0          PU        2.0          NaN       584
# 446       NaN        NaN          NaN  447arrvd
#
# [15 rows x 33 columns]

# %%
test_dict_t
content = json.dumps(test_dict_t, cls=NpEncoder) 
content

client = storage.Client()
bucket = client.get_bucket(bucketName)
blob = bucket.blob("testing1.json")

blob.upload_from_string(content, "application/json")

# %%
testing = test_dict_t
testing
content = json.dumps(testing, cls=NpEncoder) 
content
# Out:
# '{"code": 0, "summary": {"cost": 66869, "unassigned": 0, "delivery": [158], "amount": [158], "pickup": [0], "service": 47400, "duration": 66869, "waiting_time": 0, "distance": 953583, "computing_times": {"loading": 114, "solving": 6072, "routing": 56}}, "unassigned": [], "routes": [{"vehicle": 447, "cost": 4048, "delivery": [13], "amount": [13], "pickup": [0], "service": 3900, "duration": 4048, "waiting_time": 0, "distance": 43559, "steps": [{"type": "start", "location": [101.9381, 2.7297], "load": [13], "arrival": 31500, "duration": 0, "distance": 0, "name": "rafinord"}, {"type": "job", "location": [101.9168708, 2.7047421], "job": 7589, "service": 300, "waiting_time": 0, "load": [12], "arrival": 31844, "duration": 344, "distance": 5841, "description": "Jalan Rumbia, Kampung Seberang Paya, 11900 Bayan Lepas, Pulau Pinang"}, {"type": "job", "location": [101.9159438, 2.7010402], "job": 574, "service": 300, "waiting_time": 0, "load": [11], "arrival": 32223, "duration": 423, "distance": 6389, "description": "WAREHOUSE NO. 1, JALAN HARUAN 1, OAKLAND INDUSTRIAL PARK, SEREMBAN"}, {"type": "job", "location": [101.9175238, 2.6953908], "job": 575, "service": 300, "waiting_time": 0, "load": [10], "arrival": 32644, "duration": 544, "distance": 7372, "description": "NO 277 JALAN HARUAN 1 OAKLAND INDUSTRIAL PARK 70300 SEREMBAN 2, SEREMBAN,"}, {"type": "job", "location": [101.9236249, 2.688915], "job": 578, "service": 300, "waiting_time": 0, "load": [9], "arrival": 33162, "duration": 762, "distance": 9275, "description": "NO;52,JALAN S2 C2, GREEN TECHNOLOGY PARK, SEREMBAN"}, {"type": "job", "location": [101.9266453, 2.6848554], "job": 579, "service": 300, "waiting_time": 0, "load": [8], "arrival": 33669, "duration": 969, "distance": 10476, "description": "NO247,JALAN S2-C11,GREEN TECHNOLOGY PARK,70300 SEREMBAN2,NEGERI SEREMBAN"}, {"type": "job", "location": [101.8980233, 2.6777029], "job": 587, "service": 300, "waiting_time": 0, "load": [7], "arrival": 34411, "duration": 1411, "distance": 15607, "description": "PT NO 13757 JALAN HARUAN 1 OAKLAND INDUSTRIAL PARK SEREMBAN"}, {"type": "job", "location": [101.8764521, 2.6598506], "job": 586, "service": 300, "waiting_time": 0, "load": [6], "arrival": 35292, "duration": 1992, "distance": 21417, "description": "NO1773 JALAN NUSARI 7/8 . ."}, {"type": "job", "location": [101.8569069, 2.6724919], "job": 585, "service": 300, "waiting_time": 0, "load": [5], "arrival": 36080, "duration": 2480, "distance": 24863, "description": "NO 705, JALAN HIJAYU 3/19, HIJAYU 3 SEREMBAN"}, {"type": "job", "location": [101.9085892, 2.6872418999999996], "job": 580, "service": 300, "waiting_time": 0, "load": [4], "arrival": 37126, "duration": 3226, "distance": 33752, "description": "387 CITY HOMES ACACIA JALAN S2 D14 SEREMBAN"}, {"type": "job", "location": [101.9111368, 2.691144], "job": 581, "service": 300, "waiting_time": 0, "load": [3], "arrival": 37542, "duration": 3342, "distance": 34505, "description": "242, JALAN S2 D3, CITY HOMES, SEREM 70300 SEREMBAN, NEGERI SEMBILAN, MA SEREMBAN"}, {"type": "job", "location": [101.9107812, 2.6940046000000004], "job": 582, "service": 300, "waiting_time": 0, "load": [2], "arrival": 38059, "duration": 3559, "distance": 36299, "description": "C/O FRISBERG AUTOMATION 223-1, JALAN S2 B10, UPTOWN AVENUE SEREMBAN 2"}, {"type": "job", "location": [101.9123992, 2.7015334], "job": 583, "service": 300, "waiting_time": 0, "load": [1], "arrival": 38491, "duration": 3691, "distance": 37531, "description": "LOT F36 1ST FLOOR, JUSCO SEREMBAN 2 SHOPPING CENTRE,112 PRSN S2 B1, 70 N.SEMBILA SEREMBAN"}, {"type": "job", "location": [101.9112658, 2.7028797000000004], "job": 584, "service": 300, "waiting_time": 0, "load": [0], "arrival": 38822, "duration": 3722, "distance": 37803, "description": "242, JALAN S2 D3, CITY HOMES, SEREM 70300 SEREMBAN, NEGERI SEMBILAN, MA SEREMBAN"}, {"type": "end", "location": [101.9381, 2.7297], "load": [0], "arrival": 39448, "duration": 4048, "distance": 43559}], "geome ...

# %%
for route in routesIDs:
    vehicleInformation = fullDataFrame.loc[fullDataFrame['id'] == route[0]]
    partialDataFrame = fullDataFrame.loc[fullDataFrame['id'].isin(route)]

# %%
counter = 1
for route in routesIDs:
    vehicleInformation = fullDataFrame.loc[fullDataFrame['id'] == route[0]]
    partialDataFrame = fullDataFrame.loc[fullDataFrame['id'].isin(route)]
    
    date = vehicleInformation["Act Dt"].values[0]
    name = vehicleInformation["Courier id"].values[0]
    
    #update the job courier id match with vehicle
    partialDataFrame["Courier id"] = name
#     string = "routes/"+ str(date) + "/" + session  + "/" + name + ".csv"
    partialDataFrame['id'] = partialDataFrame['id'].astype('category')
    not_in_list = partialDataFrame['id'].cat.categories.difference(route)
    partialDataFrame['id'] = partialDataFrame['id'].cat.set_categories(np.hstack((route, not_in_list)), ordered=True)

    partialDataFrame = partialDataFrame.sort_values('id')
#     partialDataFrame.to_csv("routes/"+ str(date) + "/" +session  + "/" + name + ".csv")
    partialDataFrame.to_csv("routes/"+ str(date) + "/" +session  + "/" + str(counter) + ".csv")
    
    counter=counter+1
    
#     print(type(route[0]))
# print(vehicleInformation)
partialDataFrame

# test.to_csv("testing.csv")
# print(route)
# Out:
#     PUD Svc Area PUD Fac PUD Rte PUD Cycle Courier id     Courier Type  \
# 599          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 600          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 601          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 602          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 603          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 604          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 605          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 606          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 607          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 608          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 609          KUL     EAC    ACC1         B    kumaraj  Service Partner
# 765          KUL     EAC    ACY1         B    kumaraj              NaN
#
#                            Customer Name  \
# 599                              JOE LEE
# 600         FRENCH MALAYSIAN HOLDINGS SB
# 601     HENGYUAN REFINING COMPANY BERHAD
# 602       SHELL MALAYSIA TRADING SDN BHD
# 603  PETRON MALAYSIA REFINING & MARKETIN
# 604  PETRON MALAYSIA REFINING AND MARKET
# 605   CABOT MATERIALS RESEARCH SDN. BHD.
# 606  PETRON MALAYSIA REFINING AND MARKET
# 607        HENGYUAN REFINING COMPANY BHD
# 608                 HENGYUAN REFINING CO
# 609     HENGYUAN REFINING COMPANY BERHAD
# 765                                  NaN
#
#                                                 Street    zip          City  \
# 599  123A, MAIN ROAD\n71200 RANTAU NEGERI SEMBILAN\...  71200        RANTAU
# 600  931 JALAN DS3 1\nBANDAR DATARAN SEGAR .\nPORT ...  71010  PORT DICKSON
# 601  BATU 1 JALAN PANTAI\nHENGYUAN REFINING COMPANY...  71000  PORT DICKSON
# 602  PORT DICKSON LOBP BATU 1\nJALAN PANTAI 70\nPOR...  71000  PORT DICKSON
# 603  PORT DICKSON TERMINAL\nBATU 1-1/2, JALAN PANTA...  71010  PORT DICKSON
# 604  OAB, PORT DICKSON REFINERY, 1 1/2\nMILES OFF J...  71009  PORT DICKSON
# 605  BATU 2 JALAN PANTAI\nP.O. BOX 30 70\nPORT DICKSON  71000  PORT DICKSON
# 606  OAB,PORT DICKSON REFINERY 1 1/2 MIL\nJALAN PAN...  71009  PORT DICKSON
# 607            BATU 1 JALAN PANTAI\n. 70\nPORT DICKSON  71000  PORT DICKSON
# 608                              BATU 1 JALAN PANTAI .  71000  PORT DICKSON
# 609                           BATU 1, JALAN PANTAI\n\n  71000  PORT DICKSON
# 765                                                NaN    NaN           NaN
#
#      ...   Open Closed       lat        lgtd         awb_booking  \
# 599  ...    NaN  23:59  2.587046  101.961776          9196068593
# 600  ...    NaN  23:59  2.559709  101.818909          7344318284
# 601  ...  11:00  16:30  2.528193  101.810031          9629784463
# 602  ...  11:00  16:30  2.528821  101.821592          9629721161
# 603  ...    NaN  23:59  2.528710  101.821529          3464318255
# 604  ...    NaN  23:59  2.528753  101.821478          3464296441
# 605  ...   9:30  15:00  2.522055  101.831740          9629684595
# 606  ...  14:00  17:00  2.529432  101.823339          6904685432
# 607  ...  12:30  16:30  2.527400  101.807848          1041537685
# 608  ...  12:45  16:30  2.527400  101.807848  057591 - 550402941
# 609  ...  13:00  18:00  2.536566  101.795128          6904450910
# 765  ...    NaN    NaN  2.818160  101.788425                 NaN
#
#     Act Ckpt Code  PuD Type  Stop Code  MarkerColor     id
# 599            OK        DL        1.0          NaN  597.0
# 600            OK        DL        2.0          NaN  598.0
# 601            PU        PU        1.0          NaN  599.0
# 602            PU        PU        2.0          NaN  600.0
# 603            OK        DL        3.0          NaN  601.0
# 604            OK        DL        4.0          NaN  602.0
# 605            PU        PU        3.0          NaN  603.0
# 606            PU        PU        4.0          NaN  604.0
# 607            PU        PU        5.0          NaN  605.0
# 608            FP        FP        1.0          NaN  606.0
# 609            PU        PU        6.0          NaN  607.0
# 765         DEPAR       NaN        NaN          NaN  763.0
#
# [12 rows x 33 columns]

# %%
date = "20200204"
session = "m"
street = "Jalan Rumbia, Kampung Seberang Paya, 11900 Bayan Lepas, Pulau Pinang"
street = "No. 765, Jalan Sua Betong, 71200, Rantau, Negeri Sembilan"

    
# def findTheAddedJobRouteInformation():
    
abc = tryGotUnassignedInResponse2(date,session,street)
# responseFile =

# try = updateCSVToGStorage(abc[""])

# %%
def updateCSVToGStorage(awb_booking):
    client = storage.Client()
    bucket = client.get_bucket(bucketName)
    fullDataFrame = pd.read_csv(gStorage)
    fullDataFrame["awb_booking"] = fullDataFrame['awb_booking'].astype(str)
    rowToUpdate = fullDataFrame.loc[(fullDataFrame["awb_booking"] == awb_booking )]
    if( len(rowToUpdate.index) != 0):
        session = awb_booking.split("_")[0]
        session = "m"
        dict_t = getResponseFileAsDict()

        ID = rowToUpdate.iloc[0]["id"]
        route, indexStep, vehicleID = getRouteDetailWithID(ID)
        if(route != [] or indexStep != [] or vehicleID != []):
            print(rowToUpdate.index[0])
            arrivalTime = route["steps"][indexStep]["arrival"]

            vehicleInformation = fullDataFrame.loc[(fullDataFrame ["id"] == vehicleID )]
            if(len(vehicleInformation.index) != 0):
                vehicleInformation = vehicleInformation.reset_index(drop = True)
                if(len(rowToUpdate.index) != 0):
                    fullDataFrame.at[rowToUpdate.index[0].astype(int), "Courier Type"] = vehicleInformation.iloc[0]["Courier Type"]
                    fullDataFrame.at[rowToUpdate.index[0], "PUD Svc Area"] = vehicleInformation.iloc[0]["PUD Svc Area"]
                    fullDataFrame.at[rowToUpdate.index[0], "PUD Fac"] = vehicleInformation.iloc[0]["PUD Fac"]
                    fullDataFrame.at[rowToUpdate.index[0], "PUD Rte"] = vehicleInformation.iloc[0]["PUD Rte"]
                    fullDataFrame.at[rowToUpdate.index[0], "PUD Cycle"] = vehicleInformation.iloc[0]["PUD Cycle"]
                    fullDataFrame.at[rowToUpdate.index[0], "Courier id"] = vehicleInformation.iloc[0]["Courier id"]
                    fullDataFrame.at[rowToUpdate.index[0], "Act Tm"] = getTime24hour(arrivalTime)
                    string = fullDataFrame.to_csv(None, index=False)
                    blob = bucket.blob("3.csv")
                    blob.upload_from_string(string, "application/vnd.ms-excel")
                    return True
                else:
                    return {"Error" : "vehicleID not found in db"}
            else:
                return {"Error" : "ID not found in db"}
        else:
            return {"Error" : "ID not found in route"}
    else:
#         print(type(awb_booking))
#         print(type(fullDataFrame["awb_booking"][0]))
#         print(rowToUpdate)
        dbAwb = fullDataFrame.iloc[447]["awb_booking"]
        return {"Error" : "awb_booking not found in db."}

testing = updateCSVToGStorage( abc["extra"]["awb_booking"] )
testing

# %%
route, indexStep, vehicleID = getRouteDetailWithID(448)

response = abc
# print(response["routes"])

#first row
# vehicleInformation = fullDataFrame.loc[(fullDataFrame ["id"] == vehicleID )]
# stepsInformation = fullDataFrmae.iloc(fullDataFrame["id"] == 1)

# print(route["steps"])


ids = []
ids.append(vehicleID)
for indexStep, step in enumerate( routes["steps"], start = 1):
    if(step["type"] == "job"):
        ids.append(step["job"])

print(ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1fc2144d8b5a> in <module>
# ----> 1 route, indexStep, vehicleID = getRouteDetailWithID(448)
#       2
#       3 response = abc
#       4 # print(response["routes"])
#       5
#
# NameError: name 'getRouteDetailWithID' is not defined

# %%
readed["routes"]

# readed["routes"]["steps"]



toPrint = getRouteDetail(500)

toPrint
# readed
# Out:
# ([[101.9381, 2.7297],
#   [101.942542, 2.7251453999999997],
#   [101.9552125, 2.723318],
#   [101.9536736, 2.6960765],
#   [101.9300755, 2.6957107999999996],
#   [101.9235314, 2.7024502],
#   [101.916898, 2.704746],
#   [101.9166755, 2.7047494],
#   [101.9166878, 2.7047096],
#   [101.9167236, 2.7047272],
#   [101.9167518, 2.7045911],
#   [101.9166245, 2.7047882999999997],
#   [101.9164988, 2.7048625],
#   [101.9164423, 2.7047654],
#   [101.916676, 2.7048283],
#   [101.9166613, 2.7048186000000003],
#   [101.9167006, 2.7048400000000004],
#   [101.9159438, 2.7010402],
#   [101.9175238, 2.6953908],
#   [101.9236249, 2.688915],
#   [101.9266453, 2.6848554],
#   [101.8980233, 2.6777029],
#   [101.9085892, 2.6872418999999996],
#   [101.9111368, 2.691144],
#   [101.9107812, 2.6940046000000004],
#   [101.9123992, 2.7015334],
#   [101.9112658, 2.7028797000000004],
#   [101.9390577, 2.7259512000000004],
#   [101.938135, 2.7284237],
#   [101.9381, 2.7297]],
#  [101.9167518, 2.7045911],
#  5)

# %%
dict_t = {"1" : "ASDas", "2" : "adsdsadas"}
dict_t["2"]

if(dict_t["1"] != "ASDas" and dict_t["3"] == "asdas"):
    print("true")

# %%
import datetime

from flask import Flask, render_template

# [START gae_python37_datastore_store_and_fetch_times]


# [END gae_python37_datastore_store_and_fetch_times]
app = Flask(__name__)

# morningData = tryGotUnassignedInResponse2(date,session,street)


# [START gae_python37_datastore_render_times]
@app.route('/')
def start():
    # morningData = tryGotUnassignedInResponse(date,session,street)
    print("start")
    return "Hello"
# def root():

@app.route('/try')
def tryReturn():
    # date = "20200204"
    # session = "m"
    # street = "Jalan Rumbia, Kampung Seberang Paya, 11900 Bayan Lepas, Pulau Pinang"
# example
# http://127.0.0.1:8080/try?date=20200204&session=m&street=Bj%20Court%20Condominium,%20Kampung%20Seberang%20Paya,%2011900%20Bayan%20Lepas,%20Pulau%20Pinang
    from flask import request
    date  = request.args.get('date')
    session = request.args.get('session')
    street = request.args.get('street')

    # street = "Bj Court Condominium, Kampung Seberang Paya, 11900 Bayan Lepas, Pulau Pinang"
    morningData = tryGotUnassignedInResponse2(date,session,street)
    return morningData
    # print(type(date))
    # return street

# [END gae_python37_datastore_render_times]


@app.route('/openFile')
def openFile():
    from flask import Flask
    from io import StringIO
    from flask import jsonify
    client = storage.Client()
    bucket = client.get_bucket('real-bucket-dhl')
    
    blob = bucket.get_blob('3.csv')
    your_file_contents = blob.download_as_string()

    # df = pd.read_csv(StringIO(your_file_contents))
    df = pd.read_csv('gs://real-bucket-dhl/3.csv')

    # fullDataFrame = pd.read_csv(blob)
    # return your_file_contents
    # print(df.iloc[0]["Courier id"])

    return jsonify(df.iloc[0]["Courier id"])




@app.route('/uploadfile')
def upload_blob():
    client = storage.Client()
    bucket = client.get_bucket("real-bucket-dhl")
    
    # fullDataFrame = pd.read_csv(csvPath)
    df = pd.read_csv('gs://real-bucket-dhl/3.csv')
    string = df.to_csv(None, index=False)

    blob = bucket.blob("3.csv")

    blob.upload_from_string(string, "application/vnd.ms-excel")

@app.route('/test')
def another_function():

    from flask import request
    a  = request.args.get('first')
    b = request.args.get('second')
    return a + b

if __name__ == '__main__':
    # This is used when running locally only. When deploying to Google App
    # Engine, a webserver process such as Gunicorn will serve the app. This
    # can be configured by adding an `entrypoint` to app.yaml.

    # Flask's development server will automatically serve static files in
    # the "static" directory. See:
    # http://flask.pocoo.org/docs/1.0/quickstart/#static-files. Once deployed,
    # App Engine itself will serve those files as configured in app.yaml.
    app.run(host='127.0.0.1', port=8080, debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\lun\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
